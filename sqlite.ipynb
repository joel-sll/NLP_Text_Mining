# %% [markdown]
# SQLITE

# %%
import sqlite3
import os
try:
    import pyarrow
except:
    # %pip install pyarrow
    import pyarrow

try:
    import pandas as pd
except:
    # %pip install pandas
    import pandas as pd

import json
import re

print("done")
# Out:
# done

# %% [markdown]
# Loading files

# %%
class DButils:
    def __init__(self, path: str, filename: str, exists_ok: bool =False):
        """
        Initialize a new sqlite database.

        Args:
            path (str): Path to the sqlite database file.
            filename (str): name of the sqlite file.
            exists_ok (bool): will thow an error if the database already exists if exists_ok is False.

        Notes:
            If the file does not exist, it will be created.
        """
        
        if not exists_ok and \
            os.path.exists(os.path.join(path, filename)):
            raise FileExistsError(f"Database {filename} already exists at {path}.")

        os.makedirs(path, exist_ok=True)
        self.PATH_TO_DB = os.path.join(path, filename)

    def is_table(self, table_name: str) -> bool:
        with sqlite3.connect(self.PATH_TO_DB) as conn:
            cursor = conn.cursor()
            cursor.execute(
            "SELECT 1 FROM sqlite_master WHERE type='table' AND name=?", (table_name.upper(),)
            )
            return cursor.fetchone() is not None
        
    def create_table(self, table_name: str, schema: dict):
        schema_str = ", ".join(f"{col} {col_type}" for col, col_type in schema.items())

        with sqlite3.connect(self.PATH_TO_DB) as conn:
            cursor = conn.cursor()
            cursor.execute("PRAGMA foreign_keys = ON")
            cursor.execute(f"CREATE TABLE {table_name.upper()} ({schema_str})")
            return True
        
        
    def insert(self, table_name: str, data: dict[str, any]) -> bool:

        columns = ", ".join(data.keys())
        values = tuple(data.values())
        placeholders = ", ".join("?" for _ in data)
        
        sql = f"INSERT INTO {table_name} ({columns}) VALUES ({placeholders})"
        #print(sql)
        try:
            with sqlite3.connect(self.PATH_TO_DB) as conn:
                cursor = conn.cursor()
                cursor.execute("PRAGMA foreign_keys = ON")
                cursor.execute(sql, values)
                conn.commit()
                return True
        except sqlite3.Error as e:
            print(f"Error inserting data into table '{table_name}': {e}")
            return False
        
    def insert_restaurant(self, restaurant: pd.DataFrame):
        address = pd.DataFrame()
        address[["ADDRESS", "OTHER"]] = restaurant["address"].str.split(", ", expand=True)
        address[["POSTAL_CODE", "CITY", "COUNTRY"]] = address["OTHER"].str.split(" ", expand=True)
        address.drop(columns=["OTHER"], inplace=True)
        address = {key: value.iloc[0] for key, value in address.items()}

        restaurant_keys = [col for col in restaurant.columns if col not in ["address", "photos", "reviews", "geographic_location"]]
        restaurant_dict = {key: restaurant[key].iloc[0] for key in restaurant_keys}
        restaurant_dict["opening_hours"] = json.dumps(restaurant_dict["opening_hours"].tolist(), ensure_ascii=False)
        restaurant_dict["ranking"] = json.dumps(restaurant_dict["ranking"], ensure_ascii=False)
        restaurant_dict["detailed_rating"] = json.dumps(restaurant_dict["detailed_rating"], ensure_ascii=False)
        restaurant_dict["details"] = json.dumps({key: json.dumps(val.tolist(), ensure_ascii=False) for key, val in restaurant_dict["details"].items()}, ensure_ascii=False)
        restaurant_dict["address"] = address["ADDRESS"]
        restaurant_dict["postal_code"] = address["POSTAL_CODE"]
        restaurant_dict["city"] = address["CITY"]
        restaurant_dict["country"] = address["COUNTRY"]

        with sqlite3.connect(self.PATH_TO_DB) as conn:
            cursor = conn.cursor()
            cursor.execute("PRAGMA foreign_keys = ON")
            cursor.execute("SELECT ID_COUNTRY from COUNTRY WHERE COUNTRY=?", (restaurant_dict["country"],))
            country_id = cursor.fetchone()
            if not country_id:
                self.insert("country", {"country": restaurant_dict["country"]})
                country_id = [cursor.lastrowid]
            country_id = country_id[0]

            cursor.execute("SELECT ID_POSTAL_CODE from POSTAL_CODE WHERE POSTAL_CODE=?", (restaurant_dict["postal_code"],))
            postal_code_id = cursor.fetchone()
            if not postal_code_id:
                self.insert("postal_code", {"postal_code": restaurant_dict["postal_code"]})
                postal_code_id = [cursor.lastrowid]
            postal_code_id = postal_code_id[0]


            cursor.execute("SELECT ID_CITY from CITY WHERE CITY_NAME=?", (restaurant_dict["city"],))
            city_id = cursor.fetchone()
            if not city_id:
                self.insert("city", {"city_name": restaurant_dict["city"], "ID_postal_code": postal_code_id})
                city_id = [cursor.lastrowid]
            city_id = city_id[0]

            restaurant_dict["restaurant_name"] = restaurant_dict.pop("name")
            restaurant_dict["city"] = city_id
            restaurant_dict["postal_code"] = postal_code_id
            restaurant_dict["country"] = country_id 

            self.insert("restaurant", restaurant_dict)
            restaurant_id = self.fetch_Foreignkey("restaurant", "restaurant_name", restaurant_dict["restaurant_name"])

            for desc, url in restaurant["photos"][0].items():
                photo_dict = {
                'ID_RESTAURANT': restaurant_id[0],
                'DESCRIPTION': desc,
                'URL': url
                }
                self.insert("photos", photo_dict)

            for review in restaurant["reviews"].iloc[0]:
                r_dict = {}

                r_dict["ID_RESTAURANT"] = restaurant_id[0]
                r_dict["REVIEW_DAY"] = review["review_date"]["day"]
                r_dict["review_month"] = review["review_date"]["month"]
                r_dict["review_year"] = review["review_date"]["year"]
                # Invalid values for review["visit_date"]["year"] indicate the fields were missing
                if re.match(r"\d{4}", review["visit_date"]["year"]):
                    r_dict["visit_month"] = review["visit_date"]["month"]
                    r_dict["visit_year"] = review["visit_date"]["year"]
                    r_dict["visit_context"] = review["visit_context"]
                else:
                    r_dict["visit_month"] = None
                    r_dict["visit_year"] = None
                    r_dict["visit_context"] = None
                db_tripadvisor.insert("REVIEWS", r_dict)


    def fetch_Foreignkey(self, table_name, var_name, value):
        with sqlite3.connect(self.PATH_TO_DB) as conn:
            cursor = conn.cursor()
            cursor.execute("PRAGMA foreign_keys = ON")
            cursor.execute(f"SELECT ID_{table_name} from {table_name} WHERE {var_name}=?", (value,))
            FK = cursor.fetchone()
        return FK

db_tripadvisor = DButils(path="./", filename="tripadvisor.db", exists_ok=True)

# %%
def drop_all_tables(db_path: str):
    # Connect to the SQLite database
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    
    # Get the list of all table names from sqlite_master
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()

    # Drop each table
    for table in tables:
        table_name = table[0]
        print(f"Dropping table: {table_name}")
        cursor.execute(f"DROP TABLE IF EXISTS {table_name}")
    
    # Commit the changes and close the connection
    conn.commit()
    conn.close()


country_schema = {
    "ID_COUNTRY": "INTEGER PRIMARY KEY",
    "COUNTRY": "TEXT"
}

postal_code_schema = {
    "ID_POSTAL_CODE": "INTEGER PRIMARY KEY",
    "POSTAL_CODE": "TEXT"
}

city_schema = {
    "ID_CITY": "INTEGER PRIMARY KEY",
    "ID_COUNTRY": "INTEGER REFERENCES COUNTRY(ID_COUNTRY)",
    "ID_POSTAL_CODE": "INTEGER REFERENCES CODE_POSTAL(ID_POSTAL_CODE)",
    "CITY_NAME": "TEXT"
}

restaurant_schema = {
    "ID_RESTAURANT": "INTEGER PRIMARY KEY",
    "SOURCE_PAGE": "TEXT UNIQUE",
    "RESTAURANT_NAME": "TEXT",
    "CLAIMED": "BOOLEAN",
    "PRICE_RANGE": "TEXT",
    "ADDRESS": "TEXT",
    "POSTAL_CODE": "INTEGER REFERENCES CODE_POSTAL(ID_POSTAL_CODE)",
    "CITY": "INTEGER REFERENCES CITY(ID_CITY)",
    "COUNTRY": "INTEGER REFERENCES COUNTRY(ID_COUNTRY)",
    "PHONE_NUMBER": "TEXT",
    "OPENING_HOURS": "TEXT",
    "TRAVELERS_CHOICE": "TEXT",
    "DETAILED_RATING": "TEXT",
    "DETAILS": "TEXT",
    "REVIEW_NUMBER": "INTEGER",
    "OVERALL_RATING": "REAL",
    "RANKING": "TEXT"
}

photos_schema = {
    "ID_PHOTO": "INTEGER PRIMARY KEY",
    "ID_RESTAURANT": "INTEGER REFERENCES RESTAURANT(ID_RESTAURANT)",
    "DESCRIPTION": "TEXT",
    "URL": "TEXT"
}

reviews_schema = {
    "ID_REVIEW": "INTEGER PRIMARY KEY",
    "ID_RESTAURANT": "INTEGER REFERENCES RESTAURANT(ID_RESTAURANT)",
    "N_CONTRIB": "INTEGER",
    "REVIEW_TITLE": "TEXT",
    "REVIEW_BODY": "TEXT",
    "REVIEW_SCORE": "REAL",
    "REVIEW_DAY": "TEXT",
    "REVIEW_MONTH": "TEXT",
    "REVIEW_YEAR": "TEXT",
    "VISIT_MONTH": "TEXT",
    "VISIT_YEAR": "TEXT",
    "VISIT_CONTEXT": "TEXT"
}

schemas = {
    "country": country_schema,
    "postal_code": postal_code_schema,
    "city": city_schema,
    "restaurant": restaurant_schema,
    "photos": photos_schema,
    "reviews": reviews_schema
}


# Pour effacer les tables en lien avec la table restaurant.
drop_all_tables(db_tripadvisor.PATH_TO_DB)
db_tripadvisor.create_table("country", country_schema)
db_tripadvisor.create_table("city", city_schema)
db_tripadvisor.create_table("postal_code", postal_code_schema)
db_tripadvisor.create_table("restaurant", restaurant_schema)
db_tripadvisor.create_table("photos", photos_schema)
db_tripadvisor.create_table("reviews", reviews_schema)
# Out:
# Dropping table: COUNTRY
# Dropping table: CITY
# Dropping table: POSTAL_CODE
# Dropping table: RESTAURANT
# Dropping table: PHOTOS
# Dropping table: REVIEWS
# True

# %%
parquet_files = [file for file in os.listdir() if ".parquet" in file]
for file in parquet_files:
    print(f"adding{file}")
    df = pd.read_parquet(file)
    db_tripadvisor.insert_restaurant(df)
# Out:
# addingAromatic Restaurant.parquet
# addingBLO Restaurant.parquet
# addingL'Argot.parquet
# addingL'Institut Restaurant.parquet
# addingLa Gargotte.parquet
# addingLe Boeuf D'argent.parquet
# addingLe Casse Museau.parquet
# addingMama Restaurant Lyon.parquet
# addingRestaurant Le Musée.parquet

# %%
with sqlite3.connect(db_tripadvisor.PATH_TO_DB) as conn:
    cursor = conn.cursor()
    cursor.execute("SELECT * from restaurant")
    for item in cursor.fetchall():
        print(item)
# Out:
# (1, 'https://www.tripadvisor.fr/Restaurant_Review-g187265-d12337867-Reviews-Aromatic_Restaurant-Lyon_Rhone_Auvergne_Rhone_Alpes.html', 'Aromatic Restaurant', b'\x01', 'Française', "15 Rue du Chariot d'Or", 0, 0, 0, '+33 4 78 23 73 61', '["Dimanche", "Fermé ", "Lundi", "Fermé ", "Mardi", "12:00-14:0018:30-20:30", "Mercredi", "12:00-14:0018:30-20:30", "Jeudi", "12:00-14:0018:30-20:30", "Vendredi", "12:00-14:0018:30-20:30", "Samedi", "12:00-14:0018:30-20:30"]', '2024', '{"Excellent": 934, "Horrible": 5, "Moyen": 41, "Médiocre": 3, "Très bon": 135}', '{"CUISINES": "[\\"Française, \\", \\"Européenne\\"]", "FONCTIONNALITÉS": "[\\"Accessible en fauteuil roulant\\", \\"Cartes bancaires acceptées\\", \\"Chaises hautes disponibles\\", \\"Places assises\\", \\"Réservations\\", \\"Salle privée\\", \\"Sert de l\'alcool\\", \\"Service de table\\", \\"Terrasse\\"]", "Régimes spéciaux": "[\\"Convient aux végétariens\\"]", "Types de repas": "[\\"Déjeuner, \\", \\"Dîner\\"]"}', b'^\x04\x00\x00\x00\x00\x00\x00', 5.0, '{"over": 3178, "rank": 49}')
# (2, 'https://www.tripadvisor.fr/Restaurant_Review-g187265-d14913909-Reviews-BLO_Restaurant-Lyon_Rhone_Auvergne_Rhone_Alpes.html', 'BLO Restaurant', b'\x01', 'Française', '37 Rue de la Charite', 0, 1, 1, '+33 4 72 31 76 95', '["Dimanche", "Fermé ", "Lundi", "12:00-14:0019:30-22:00", "Mardi", "12:00-14:0019:30-22:00", "Mercredi", "12:00-14:0019:30-22:00", "Jeudi", "12:00-14:0019:30-22:00", "Vendredi", "12:00-14:0019:30-22:00", "Samedi", "12:00-14:0019:30-22:00"]', '2024', '{"Excellent": 241, "Horrible": 4, "Moyen": 15, "Médiocre": 10, "Très bon": 31}', '{"CUISINES": "[\\"Française, \\", \\"Steakhouse, \\", \\"Grillades, \\", \\"Brasserie gastronomique\\"]", "FONCTIONNALITÉS": "[\\"Accessible en fauteuil roulant\\", \\"Bières & \\", \\"Vins\\", \\"Cartes bancaires acceptées\\", \\"Paiements électroniques\\", \\"Places assises\\", \\"Réservations\\", \\"Salle privée\\", \\"Sert de l\'alcool\\", \\"Service de table\\", \\"Stationnement dans la rue\\", \\"Terrasse\\"]", "PRIX": "[]", "Types de repas": "[\\"Déjeuner, \\", \\"Dîner, \\", \\"Ouvert tard, \\", \\"Boissons\\"]"}', b',\x01\x00\x00\x00\x00\x00\x00', 4.5, '{"over": 3178, "rank": 65}')
# (3, 'https://www.tripadvisor.fr/Restaurant_Review-g187265-d7612326-Reviews-L_Argot-Lyon_Rhone_Auvergne_Rhone_Alpes.html', "L'Argot", b'\x01', 'Française', '132 Rue Bugeaud', 0, 1, 1, '+33 4 78 24 57 88', '["Dimanche", "Fermé ", "Lundi", "Fermé ", "Mardi", "8:00-14:00", "Mercredi", "8:00-14:00", "Jeudi", "8:00-14:0016:30-21:00", "Vendredi", "8:00-14:0016:30-21:00", "Samedi", "8:00-14:00"]', '2024', '{"Excellent": 594, "Horrible": 10, "Moyen": 22, "Médiocre": 14, "Très bon": 149}', '{"CUISINES": "[\\"Française, \\", \\"Européenne, \\", \\"Saine\\"]", "FONCTIONNALITÉS": "[\\"Accessible en fauteuil roulant\\", \\"Cartes bancaires acceptées\\", \\"American\xa0\\", \\"Express\\", \\"Chèques-cadeaux disponibles\\", \\"Mastercard\\", \\"Paiements électroniques\\", \\"Places assises\\", \\"Réservations\\", \\"Restaurants non-fumeurs\\", \\"Sert de l\'alcool\\", \\"Service de table\\", \\"Terrasse\\", \\"Visa\\"]", "PRIX": "[]", "Types de repas": "[\\"Déjeuner, \\", \\"Dîner\\"]"}', b'\x15\x03\x00\x00\x00\x00\x00\x00', 4.5, '{"over": 3178, "rank": 67}')
# (4, 'https://www.tripadvisor.fr/Restaurant_Review-g187265-d5539701-Reviews-L_Institut_Restaurant-Lyon_Rhone_Auvergne_Rhone_Alpes.html', "L'Institut Restaurant", b'\x01', 'Française', '20 Place Bellecour', 2, 1, 1, '+33 4 28 31 69 06', '["Dimanche", "Fermé ", "Lundi", "12:00-13:0019:30-21:00", "Mardi", "12:00-13:0019:30-21:00", "Mercredi", "12:00-13:0019:30-21:00", "Jeudi", "12:00-13:0019:30-21:00", "Vendredi", "12:00-13:0019:30-21:00", "Samedi", "Fermé "]', '2024', '{"Excellent": 929, "Horrible": 8, "Moyen": 53, "Médiocre": 14, "Très bon": 238}', '{"CUISINES": "[\\"Française, \\", \\"Européenne\\"]", "FONCTIONNALITÉS": "[\\"Accessible en fauteuil roulant\\", \\"Cartes bancaires acceptées\\", \\"Chaises hautes disponibles\\", \\"Chèques-cadeaux disponibles\\", \\"Places assises\\", \\"Réservations\\", \\"Salle privée\\", \\"Sert de l\'alcool\\", \\"Service de table\\"]", "PRIX": "[]", "Types de repas": "[\\"Déjeuner, \\", \\"Dîner\\"]"}', b'\xda\x04\x00\x00\x00\x00\x00\x00', 4.5, '{"over": 3178, "rank": 10}')
# (5, 'https://www.tripadvisor.fr/Restaurant_Review-g187265-d1331945-Reviews-La_Gargotte-Lyon_Rhone_Auvergne_Rhone_Alpes.html', 'La Gargotte', b'\x01', 'Française', '15 Rue Royale', 0, 1, 1, '+33 4 78 28 79 20', '["Dimanche", "Fermé ", "Lundi", "Fermé ", "Mardi", "12:00-14:0020:00-23:00", "Mercredi", "20:00-23:00", "Jeudi", "20:00-23:00", "Vendredi", "20:00-23:00", "Samedi", "20:00-23:00"]', '2024', '{"Excellent": 885, "Horrible": 14, "Moyen": 53, "Médiocre": 42, "Très bon": 174}', '{"CUISINES": "[\\"Française, \\", \\"Européenne, \\", \\"Saine\\"]", "FONCTIONNALITÉS": "[\\"Accessible en fauteuil roulant\\", \\"Bar complet\\", \\"Cartes bancaires acceptées\\", \\"Places assises\\", \\"Réservations\\", \\"Salle privée\\", \\"Sert de l\'alcool\\", \\"Service de table\\"]", "Régimes spéciaux": "[\\"Convient aux végétariens\\"]", "Types de repas": "[\\"Dîner, \\", \\"Ouvert tard\\"]"}', b'\x90\x04\x00\x00\x00\x00\x00\x00', 4.5, '{"over": 3177, "rank": 19}')
# (6, 'https://www.tripadvisor.fr/Restaurant_Review-g187265-d4993538-Reviews-Le_Boeuf_D_argent-Lyon_Rhone_Auvergne_Rhone_Alpes.html', "Le Boeuf D'argent", b'\x01', 'Française', '29 Rue du Bœuf', 0, 1, 1, '+33 4 78 38 11 20', '["Dimanche", "12:00-14:0019:00-20:30", "Lundi", "Fermé ", "Mardi", "19:00-20:30", "Mercredi", "19:00-20:30", "Jeudi", "12:00-13:3019:00-20:30", "Vendredi", "12:00-13:3019:00-20:30", "Samedi", "12:00-13:3019:00-21:00"]', '2024', '{"Excellent": 935, "Horrible": 11, "Moyen": 27, "Médiocre": 9, "Très bon": 152}', '{"CUISINES": "[\\"Française, \\", \\"Fusion\\"]", "FONCTIONNALITÉS": "[\\"Accessible en fauteuil roulant\\", \\"American\xa0\\", \\"Express\\", \\"Bières & \\", \\"Vins\\", \\"Cartes bancaires acceptées\\", \\"Mastercard\\", \\"Paiements électroniques\\", \\"Places assises\\", \\"Réservations\\", \\"Restaurants non-fumeurs\\", \\"Visa\\"]", "Régimes spéciaux": "[\\"Convient aux végétariens\\"]", "Types de repas": "[\\"Déjeuner, \\", \\"Dîner\\"]"}', b'm\x04\x00\x00\x00\x00\x00\x00', 5.0, '{"over": 3178, "rank": 16}')
# (7, 'https://www.tripadvisor.fr/Restaurant_Review-g187265-d949361-Reviews-Le_Casse_Museau-Lyon_Rhone_Auvergne_Rhone_Alpes.html', 'Le Casse Museau', b'\x01', 'Française', '2 Rue Chavanne', 4, 1, 1, '+33 4 78 32 64 42', '["Dimanche", "Fermé ", "Lundi", "Fermé ", "Mardi", "12:00-14:0019:00-22:00", "Mercredi", "12:00-14:0019:00-22:00", "Jeudi", "12:00-14:0019:00-22:00", "Vendredi", "12:00-14:0019:00-22:00", "Samedi", "12:00-14:0019:00-22:00"]', '2024', '{"Excellent": 340, "Horrible": 5, "Moyen": 11, "Médiocre": 2, "Très bon": 53}', '{"CUISINES": "[\\"Française\\"]", "FONCTIONNALITÉS": "[\\"American\xa0\\", \\"Express\\", \\"Bières & \\", \\"Vins\\", \\"Cartes bancaires acceptées\\", \\"Mastercard\\", \\"Paiements électroniques\\", \\"Places assises\\", \\"Réservations\\", \\"Restaurants non-fumeurs\\", \\"Sert de l\'alcool\\", \\"Service de table\\", \\"Visa\\", \\"Wi-\\", \\"Fi gratuit\\"]", "PRIX": "[]", "Types de repas": "[\\"Déjeuner, \\", \\"Dîner\\"]"}', b'\x9b\x01\x00\x00\x00\x00\x00\x00', 5.0, '{"over": 3177, "rank": 7}')
# (8, 'https://www.tripadvisor.fr/Restaurant_Review-g187265-d4059959-Reviews-Mama_Restaurant_Lyon-Lyon_Rhone_Auvergne_Rhone_Alpes.html', 'Mama Restaurant Lyon', b'\x01', 'Française', '13 Rue Domer', 0, 1, 1, '+33 4 78 02 58 58', '["Dimanche", "19:00-23:00", "Lundi", "12:00-15:0019:00-23:00", "Mardi", "12:00-15:0019:00-23:00", "Mercredi", "12:00-15:0019:00-23:00", "Jeudi", "12:00-15:0019:00-0:00", "Vendredi", "12:00-15:0019:00-0:00", "Samedi", "12:00-15:0019:00-0:00"]', '', '{"Excellent": 564, "Horrible": 68, "Moyen": 207, "Médiocre": 121, "Très bon": 501}', '{"CUISINES": "[\\"Française, \\", \\"Bars-restaurants\\"]", "FONCTIONNALITÉS": "[\\"Accessible en fauteuil roulant\\", \\"American\xa0\\", \\"Express\\", \\"Bar complet\\", \\"Bières & \\", \\"Vins\\", \\"Buffet\\", \\"Cartes bancaires acceptées\\", \\"Chaises hautes disponibles\\", \\"Chèques-cadeaux disponibles\\", \\"Chiens acceptés\\", \\"Concerts\\", \\"Mastercard\\", \\"Places assises\\", \\"Réservations\\", \\"Salle privée\\", \\"Sert de l\'alcool\\", \\"Service de table\\", \\"Style familial\\", \\"Télévision\\", \\"Terrasse\\", \\"Visa\\", \\"Wi-\\", \\"Fi gratuit\\"]", "Régimes spéciaux": "[\\"Convient aux végétariens, \\", \\"Options végétaliennes\\"]", "Types de repas": "[\\"Petit déjeuner, \\", \\"Déjeuner, \\", \\"Dîner, \\", \\"Brunch, \\", \\"Ouvert tard\\"]"}', b'\xb5\x05\x00\x00\x00\x00\x00\x00', 4.0, '{"over": 3177, "rank": 221}')
# (9, 'https://www.tripadvisor.fr/Restaurant_Review-g187265-d1395616-Reviews-Restaurant_Le_Musee-Lyon_Rhone_Auvergne_Rhone_Alpes.html', 'Restaurant Le Musée', b'\x00', 'Française', '2 Rue des Forces', 2, 1, 1, '+33 4 78 37 71 54', '["Dimanche", "Fermé ", "Lundi", "Fermé ", "Mardi", "12:00-14:0019:30-21:30", "Mercredi", "12:00-14:0019:30-21:30", "Jeudi", "12:00-14:0019:30-21:30", "Vendredi", "12:00-14:0019:30-21:30", "Samedi", "12:00-14:00"]', '2024', '{"Excellent": 1446, "Horrible": 11, "Moyen": 54, "Médiocre": 14, "Très bon": 364}', '{"CUISINES": "[\\"Française\\"]", "FONCTIONNALITÉS": "[\\"Cartes bancaires acceptées\\", \\"Places assises\\", \\"Réservations\\", \\"Sert de l\'alcool\\", \\"Service de table\\"]", "PRIX": "[]", "Types de repas": "[\\"Déjeuner, \\", \\"Dîner, \\", \\"Ouvert tard\\"]"}', b'a\x07\x00\x00\x00\x00\x00\x00', 4.5, '{"over": 3178, "rank": 38}')

# %%
with sqlite3.connect(db_tripadvisor.PATH_TO_DB) as conn:
    cursor = conn.cursor()
    cursor.execute("SELECT * from photos")
    for item in cursor.fetchall():
        print(item)
# Out:
# (1, 1, "Découvrez le menu du mois de Décembre à l'Aromatic !", 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/15/a1/5d/a7/decouvrez-le-menu-du.jpg?w=900&h=500&s=1')
# (2, 1, 'Foie gras du Sud-Ouest poêlé et haricots coco confits à la saucisse de Montbéliard', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/17/5f/a8/f8/foie-gras-du-sud-ouest.jpg?w=900&h=500&s=1')
# (3, 1, 'Intérieur', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0f/0f/d3/f2/aromatic.jpg?w=300&h=-1&s=1')
# (4, 1, 'Menu', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0f/ce/53/f2/menu.jpg?w=300&h=200&s=1')
# (5, 1, 'Plats', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0f/0e/d7/1b/dorade-de-corse.jpg?w=300&h=200&s=1')
# (6, 1, "Une terrasse à la Croix-Rousse pour déjeuner et dîner à l'extérieur. ", 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/10/06/17/34/une-terrasse-a-la-croix.jpg?w=900&h=-1&s=1')
# (7, 2, 'EXCELLENT', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1b/76/96/da/excellent.jpg?w=900&h=500&s=1')
# (8, 2, 'Intérieur', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/13/c4/35/38/choix-de-notre-viande.jpg?w=300&h=200&s=1')
# (9, 2, 'Menu', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/17/3f/67/f6/photo8jpg.jpg?w=300&h=200&s=1')
# (10, 2, 'Plats', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/13/c4/35/83/entrees-a-partager.jpg?w=300&h=200&s=1')
# (11, 2, 'photo Matthieu Cellard', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/14/63/4d/cc/photo-matthieu-cellard.jpg?w=900&h=500&s=1')
# (12, 3, 'Dégustation de viandes maturées', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/12/3f/f1/2c/degustation-de-viandes.jpg?w=800&h=-1&s=1')
# (13, 3, 'Faîtes vos choix ! ', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/12/3f/f1/2e/faites-vos-choix.jpg?w=900&h=500&s=1')
# (14, 3, 'Intérieur', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/08/08/48/cd/viandes-disponibles-a.jpg?w=300&h=-1&s=1')
# (15, 3, 'Menu', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/12/f6/c1/74/photo4jpg.jpg?w=300&h=200&s=1')
# (16, 3, 'Plats', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/08/08/48/be/viandes-disponibles-a.jpg?w=300&h=200&s=1')
# (17, 4, 'Intérieur', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/05/ae/1b/50/institut-paul-bocuse.jpg?w=300&h=200&s=1')
# (18, 4, "L'Institut: Monsieur Paul", 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/06/f0/c9/26/l-institut.jpg?w=900&h=500&s=1')
# (19, 4, 'Menu', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/05/ae/1c/1e/institut-paul-bocuse.jpg?w=300&h=-1&s=1')
# (20, 4, 'Plats', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/05/ae/1b/8a/institut-paul-bocuse.jpg?w=300&h=200&s=1')
# (21, 5, 'Ancienne pâtisserie vue 2', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-s/02/81/a0/51/ancienne-patisserie-vue.jpg?w=600&h=400&s=1')
# (22, 5, 'Intérieur', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-s/02/81/a0/4e/salle-de-l-ancienne-patisserie.jpg?w=300&h=-1&s=1')
# (23, 5, 'Menu', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/07/76/ee/64/la-gargotte.jpg?w=300&h=200&s=1')
# (24, 5, 'Plats', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-s/02/9a/a8/cb/filename-joli1-jpg-thumbnail0.jpg?w=300&h=-1&s=1')
# (25, 5, 'Pour des dîners à plusieurs...', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-s/02/81/a0/52/pour-des-diners-a-plusieurs.jpg?w=600&h=400&s=1')
# (26, 6, 'Dessert ', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2d/c3/df/3a/dessert.jpg?w=900&h=500&s=1')
# (27, 6, 'Intérieur', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/04/b5/26/7f/le-boeuf-d-argent.jpg?w=300&h=200&s=1')
# (28, 6, "Le Boeuf D'Argente..", 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/28/58/0b/67/le-boeuf-d-argente.jpg?w=900&h=500&s=1')
# (29, 6, 'Menu', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/09/a0/dd/28/carte.jpg?w=300&h=200&s=1')
# (30, 6, 'Plats', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/04/b5/26/af/le-boeuf-d-argent.jpg?w=300&h=200&s=1')
# (31, 6, 'Potiron', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2d/c3/df/39/potiron.jpg?w=900&h=500&s=1')
# (32, 7, 'Intérieur', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/09/d7/04/e6/le-casse-museau.jpg?w=300&h=-1&s=1')
# (33, 7, 'La carte & les menus du casse museau ', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1d/59/c6/52/la-carte-les-menus-du.jpg?w=900&h=500&s=1')
# (34, 7, 'Le Casse Museau, maison fondée en 1947 par la Tante Paulette', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1d/71/2b/33/le-casse-museau-maison.jpg?w=900&h=500&s=1')
# (35, 7, 'Logo', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1d/4b/e6/69/logo.jpg?w=600&h=400&s=1')
# (36, 7, 'Menu', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1d/59/c5/d5/la-carte-des-vins-du.jpg?w=300&h=200&s=1')
# (37, 7, 'Plats', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/09/05/63/16/le-casse-museau.jpg?w=300&h=-1&s=1')
# (38, 8, 'Intérieur', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/03/d7/04/1e/mama-shelter-restaurant.jpg?w=300&h=-1&s=1')
# (39, 8, 'Menu', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/03/d7/04/50/mama-shelter-restaurant.jpg?w=300&h=-1&s=1')
# (40, 8, 'Plats', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/03/d7/04/71/mama-shelter-restaurant.jpg?w=300&h=-1&s=1')
# (41, 8, 'Restaurant & Bar', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2d/b2/c4/eb/restaurant-bar.jpg?w=900&h=500&s=1')
# (42, 8, 'Terrace', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/2d/b2/c4/f0/terrace.jpg?w=900&h=500&s=1')
# (43, 9, 'Inside', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0f/b8/c7/b5/inside.jpg?w=900&h=500&s=1')
# (44, 9, 'Intérieur', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/03/82/21/06/le-musee.jpg?w=300&h=-1&s=1')
# (45, 9, 'Menu', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/07/55/d3/64/le-musee.jpg?w=300&h=200&s=1')
# (46, 9, 'Plats', 'https://dynamic-media-cdn.tripadvisor.com/media/photo-s/02/5c/5d/9b/samedi-soir-au-musee.jpg?w=300&h=-1&s=1')

# %%
with sqlite3.connect(db_tripadvisor.PATH_TO_DB) as conn:
    cursor = conn.cursor()
    cursor.execute("SELECT * from reviews")
    for item in cursor.fetchall():
        print(item)
# Out:
# (1, 1, 1, 'Super tout', 'Super service, super entrée, super plat et super dessert ! Produits frais et extras , nous nous sommes réglées encore une fois !', 5.0, '21', 'décembre', '2024', 'déc.', '2024', 'couples')
# (2, 1, 1, 'Excellente découverte', 'Un menu découverte fantastique avec des produits parfaitement travaillés.\n\nUn accord mets vins plein de découverte.\n\nUne ambiance chic mais décontractée \nUne équipe aux petits soins \n\nBref un super resto à faire en couple, entre amis ou même en famille pour un super RQP.\nMerci Aromatic', 5.0, '3', 'décembre', '2024', 'déc.', '2024', 'couples')
# (3, 1, 45, 'Une belle découverte', "L'accueil était chaleureux et le service impeccable.\nLa carte est variée, sans excès et les plats de qualité.\nLes vins, même au verre, sont de très belle facture.\nEt tout cela pour un prix somme toute raisonnable.\nA ne pas manquer, hormis peut être le café décevant.....mais il faut bien une petite fausse note !", 4.0, '1', 'décembre', '2024', 'nov.', '2024', 'couples')
# (4, 1, 2, 'Temps de partage et de convivialité très agréable', 'Nous avons apprécié la qualité du dîner : produits, goûts, présentation, mais aussi la gentillesse et le sourire des personnels. Nous reviendrons dans ce restaurant', 4.0, '30', 'novembre', '2024', 'nov.', '2024', 'friends')
# (5, 1, 893, 'Plat aboutis et savoureux', 'Une très bon moment entre amis!\n\nLes plats sont vraiment très bons, bien aboutis, savoureux, colorés et texturés. \nUn vrai coup de cœur pour l’œuf parfait!', 5.0, '16', 'novembre', '2024', 'nov.', '2024', 'friends')
# (6, 1, 1, 'Cuisine originale et de qualité', 'Bon dîner: délicieux amuse-bouche pour l’apéro, entrées et plats très bons avec  un bémol au niveau du dessert pour la poire blette!', 4.0, '27', 'octobre', '2024', 'oct.', '2024', 'couples')
# (7, 1, 2, 'Superbe adresse ', "Superbe adresse, des mets raffinés,  plein de saveurs et des cuissons maîtrisé. L'accord mets et vins était juste parfait. \nBravo à toute l'équipe. ", 5.0, '27', 'octobre', '2024', 'oct.', '2024', 'family')
# (8, 1, 3, 'Gastro accessible', "On m'avait recommandé l'endroit, je ne suis pas déçu du tout. \nMenu découverte, rapport qualité prix imbattable. \nL'accueil et le service chaleureux.\nJe vais le recommander a mon tour.", 5.0, '13', 'octobre', '2024', 'oct.', '2024', 'couples')
# (9, 1, 2, 'Déjeuner en amoureux', 'Une equipe agréable, un service impeccable et des plats succulents. Je recommande vivement. Les gnocchis en entrée sont a tombés, la viande est tendre, la sauce délicieuse. Nous avons passé un moment très sympathique', 5.0, '11', 'octobre', '2024', 'oct.', '2024', 'couples')
# (10, 1, 4, "Une expérience culinaire avec un goût d'inachevé", "Un restaurant agréable, rapport qualité prix un peu décevant. Service juste suffisant, beaucoup d'attente entre les plats. Cette fois ci déçu par le menu dégustation et les plats proposés. Le dessert était vraiment en dessous du reste c'est dommage", 4.0, '5', 'octobre', '2024', 'oct.', '2024', 'family')
# (11, 1, 215, 'Bon', 'Bonne cuisine, avec de bon produit. On sent bien les goûts des produits frais mais on s’attendait à un peu plus de découvert de saveur et plus surpris culinairement.\nRestaurant Conviviale \nServeuse très souriante et très avenante', 4.0, '29', 'septembre', '2024', 'sept.', '2024', 'couples')
# (12, 1, 1, 'Excellent repas dans un cadre convivial.', "Nous avons déjà diné deux fois à L'Aromatic en 3 mois, c'était une vrai claque culinaire avec un accueil chaleureux.\nNous recommandons.", 5.0, '28', 'septembre', '2024', 'sept.', '2024', 'couples')
# (13, 1, 2, 'Magnifique découverte', 'Un accueil souriant et bienveillant, une cuisine creative et raffinée, un plaisir pour les yeux et les papilles!\nNous nous sommes régalés, et recommandons chaleureusement cette excellente adresse. \nFélicitations et longue vie  à cette équipe jeune et dynamique!', 5.0, '28', 'septembre', '2024', 'sept.', '2024', 'couples')
# (14, 1, 1, 'Belle Découverte', "Belle adresse, un très bon repas! \nUn petit bémol à souligner vu l'établissement c'est le service qui nous a fait comprendre à plusieurs reprises qu'il ne fallait pas traîner..", 4.0, '17', 'septembre', '2024', 'sept.', '2024', 'couples')
# (15, 1, 2, 'Aromatic : à découvrir absolument !', "Cuisine subtile qui permet de bien apprécier toutes les saveurs, de l'amuse-bouche au dessert ! Les assiettes sont dressées simplement et avec beaucoup de raffinement, le service est juste à sa place, entre convivialité et discrétion ! \nUne superbe découverte !!!", 5.0, '11', 'septembre', '2024', 'sept.', '2024', 'friends')
# (16, 1, 55, 'Toujours une pépite !!', 'Mon ancien avis était trop ancien!\nToujours l’endroit pour passer un bon moment avec un service remarquable et une cuisine savoureuse et surprenante.\nLaissez vous bercer par le personnel en cuisine  et en salle\nFoncez', 5.0, '17', 'août', '2024', 'juil.', '2024', 'family')
# (17, 1, 4, 'Un des meilleurs restaurants de la croix rousse', 'Délicieux \nRapport qualité prix excellent \nProduits frais travaillés avec une grande finesse \nSélection de vins au top\nService attentionné', 5.0, '1', 'août', '2024', 'août', '2024', 'friends')
# (18, 1, 170, 'Une belle adresse pour découvrir une cuisine originale', "Trois menus, à prix croissant, à choisir parmi les propositions de la carte.\nLe chef a un bon tour de main, une cuisine plutôt gastronomique, des assiettes très belles dans lesquelles les produits sont bien mis en valeur et bien présentés.\nLes assaisonnements révèlent un chef de caractère.\nUn bémol : la température des bouillons sensés terminer la cuisson ou réchauffer les ravioles ou le poisson, n'est pas suffisante , donnant la sensation de manger une raviole froide ou un poisson trop cru.", 4.0, '30', 'juillet', '2024', 'juil.', '2024', 'friends')
# (19, 1, 3, 'Cuisine de qualité, accueil sans chaleur….', 'Bonne cuisine, accueil pas très sympathique. De plus, sur le principe, on peut changer les couverts entre un plat de viande et un plat de poisson, sur un menu à 45€….', 3.0, '24', 'juillet', '2024', 'juil.', '2024', 'friends')
# (20, 1, 92, 'Excellent rapport qualité / prix', 'Très bon rapport qualité / prix\nNous étions deux en terrasse, personnel accueillant, et nous avons choisi à la carte entre / plat / fromage.\nLes quantités sont suffisantes, et la qualité gustatives des plats est au rendez-vous.\nSeul bémol sur le fromage, un contenait du cumin que nous n’aimons pas, nous ne l’avons pas non plus notifié à la serveuse.', 5.0, '24', 'juillet', '2024', 'juil.', '2024', 'friends')
# (21, 1, 7, 'Excellente table à la Croix Rousse.', 'Une équipe au top tant en cuisine qu’au service. On se sent bien dans ce restaurant et on y découvre des plats succulents et inventifs. Bravo!', 5.0, '6', 'juillet', '2024', 'juil.', '2024', 'couples')
# (22, 1, 9, 'Dîner à 4', 'Très bon accueil, service efficace et souriant, plats excellens, rapport qualité / prix convenable. \nDîner en terrasse. Deux couples.', 5.0, '19', 'juin', '2024', 'juin', '2024', 'couples')
# (23, 1, 2, 'Donne le goût de revenir', 'Très agréable déjeuner, cuisine créative et personnel charmant! Le Menu du jour et la carte donne envie de revenir pour goûter l’ensemble.', 5.0, '5', 'juin', '2024', 'juin', '2024', 'family')
# (24, 1, 1, 'Très agréable !', "Nous avons passé une très belle soirée, le restaurant est très agréable. \nLes plats sont excellents, l'accord mets et vins est très recherché.\nLe rapport qualité prix est imbattable. \nNous reviendrons avec grand plaisir.", 5.0, '29', 'mai', '2024', 'mai', '2024', 'couples')
# (25, 1, 6, 'Simplement parfait', 'Toujours un régal , et toujours parfaitement accueilli … \nLe menu change régulièrement donc on ne peut pas se lasser ! Pour ceux qui hésitent encore , allez y vite !', 5.0, '21', 'mai', '2024', 'mai', '2024', 'family')
# (26, 1, 160, 'Une belle découverte', 'Plus de 1000 avis positifs que nous confirmons 1000 fois! Bravo, un cadre sympa, de belles assiettes savoureuses. Allez y mais laissons nous une place pour y revenir!', 5.0, '18', 'mai', '2024', 'mai', '2024', 'couples')
# (27, 1, 2, 'LE restaurant a ne pas manquer', 'L’endroit est magique, le chef est très sympa et la cuisine d’une qualité exceptionnelle. Un rapport qualité coût hors norme ! A vraiment essayer ou retourner. Et je ne parle pas des vins qui sont choisis avec goût et précisions.', 5.0, '8', 'mai', '2024', 'mai', '2024', 'friends')
# (28, 1, 2, 'Plaisir des yeux et des papilles', 'Comme à chacune de nos visites, un accueil agréable, des plats fins et de qualité. Tout d\'abord, un "plaisir des yeux", puis une harmonie des couleurs, et des saveurs originales.\nEn résumé, un moment de bonheur.', 5.0, '3', 'mai', '2024', 'mai', '2024', 'couples')
# (29, 1, 614, 'Une table à recommander', 'Deuxième visite de ce restaurant et toujours le même plaisir à déguster sa cuisine. Accueil et service charmant. Carte des vins sympa, juste une toute petite remarque, c’est la saison des petits poids mais n’est ce pas trop de les retrouver à la fois dans l’entrée et le plat principal', 5.0, '27', 'avril', '2024', 'avr.', '2024', 'couples')
# (30, 1, 1, 'Retrouvailles gastronomiques', "Nous avons célébré des retrouvailles entre amis. Le menu dégustation a ravi nos papilles. L'accord avec les vins etait remarquable. Le service était parfait . Nous avons passé presque trois heures à table sans etre pressés et sans attendre ! Le rythme des plats était totalement adatpé !!! Un grand moment amical et gastronomique. Merci à l'équipe de l'Aromatic!", 5.0, '24', 'avril', '2024', 'avr.', '2024', 'friends')
# (31, 1, 106, "Pour fêter l'anniversaire de ma maman", "Dîner avec ma maman pour ses 66 ans avec ce menu découverte en 5 plats excellent et un accueil chaleureux de la part de toute l'équipe. Un grand merci pour tout, ce fut une soirée à la hauteur de nos attentes.", 5.0, '20', 'avril', '2024', 'avr.', '2024', 'family')
# (32, 1, 82, 'Une très belle expérience gustative ', "A la recherche d'une idée originale pour un repas en amoureux 😉, mon choix c'est porté sur l'Aromatic. Excellent choix, c'est non seulement bon mais superbement présenté. On sens l'amour de la cuisine fine. Merci ", 5.0, '19', 'avril', '2024', 'avr.', '2024', 'couples')
# (33, 1, 1, 'Belle expérience !', 'Très belle expérience hier soir avec une amie : nous avons opté pour le menu à 45€ avec entrée, plat et dessert et choisi l’accompagnement 3 verres : un verre de vin pour chaque étape du repas , superbement choisi par le chef pour accompagner au mieux les mets …. Une mention spéciale pour le carpaccio de veau qui a émerveillé nos papilles !\nJe recommande fortement ce bel endroit et c’est sûre : j’y reviendrais !', 5.0, '16', 'avril', '2024', 'avr.', '2024', 'friends')
# (34, 1, 1, 'Quel plaisir de découvrir !', 'A partager ! Une cuisine fine et délicate dans un cadre soigné, tout comme l’accueil. Superbe expérience dans le défilé des plats et des vins, une symphonie toute en légèreté du début à la fin. Et déjà l’envie d’y revenir pour découvrir les prochains produits frais qui seront mis à l’honneur par le chef…', 5.0, '16', 'avril', '2024', 'avr.', '2024', 'friends')
# (35, 1, 141, 'Très bel endroit', 'Excellent endroit, ambiance très feutrée, service discret et agréable, cuisine raffinée, carte des vins très étendue, et de qualité, un très bel endroit où l’ont mange formidablement bien. Excellent endroit à visiter de toutes urgences ! Ce que nous voulons désormais manger, au prix juste dans un endroit élégant .. bravo', 5.0, '13', 'avril', '2024', 'avr.', '2024', 'couples')
# (36, 1, 1, 'Je recommande', 'Excellent moment culinaire (menu dégustation) et soirée très agréable. Très bon service et cadre très sympa.\nJe recommande.', 5.0, '11', 'avril', '2024', 'avr.', '2024', 'couples')
# (37, 1, 71, 'Super', 'Excellent! Produits frais et préparés avec le sourire ! Vous pouvez y aller les yeux fermés ! De notre côté nous y retournerons dès que possible !', 5.0, '9', 'avril', '2024', 'avr.', '2024', 'family')
# (38, 1, 4, 'Super', 'Délicieux repas .Accueil très sympathique \nBon rapport qualité/ Prix \nJe reviendrais c est sûr. \nPoisson cuisson parfaite !!\nDessert très très bon', 5.0, '28', 'mars', '2024', 'mars', '2024', 'family')
# (39, 1, 3, 'Un moment suspendu', "Nous avons passé un très bon moment. La salle de restaurant est très agréable. Le personnel pour le service était  à notre écoute, quand à la cuisine et les vins, nous nous sommes régalés. C'est un très bon rapport qualité prix.", 5.0, '17', 'mars', '2024', 'mars', '2024', 'friends')
# (40, 1, 9, 'Avis mitigé ', "Repas d'anniversaire de notre petit fils dans un cadre trop rustique, une échelle dans la petite salle, servis sur une table très, très rustique avec de nombreux passages des employés. Service rapide, pas de description des plats par la serveuse. Dans l'ensemble les plats sont bons sans plus. Je n'ai pas aimé l'entrée à la truite.", 3.0, '17', 'mars', '2024', 'mars', '2024', 'family')
# (41, 1, 6, 'Très belle adresse', "Très belle adresse ! Loin des zones très touristiques, ce restaurant vaut vraiment le coup : très bon accueil, très sympa, et des plats très savoureux, tant au menu qu'à la carte. Travaillés, recherchés, mais pas à l'excès. On a en plus découvert un beau Pinot noir au verre\nAu final, rapport Qualité / Prix excellent. Ce qu'on attend d'un restaurant dans la ville de la Gastronomie...mais qui devient malheureusement un peu rare\nN'hésitez pas à tester !", 5.0, '9', 'mars', '2024', 'mars', '2024', 'couples')
# (42, 1, 1, 'Bon dîner', 'Très bonne nourriture et très bon accueil. Cadre très agréable. \nUn bémol : les desserts trop sucrés.\nUn deuxième bémol : nous avons été sollicités pour un avis à la fin du repas, et avons fait part de cette remarque qui a été très mal reçue.', 4.0, '1', 'mars', '2024', 'mars', '2024', 'couples')
# (43, 1, 1, 'Meilleur rapport qualité prix de croix rousse ', "De passage dans cet établissement un midi car attiré par l'ardoise qui affichait un menu du jour à 21 euros entrée/plat et une bonne quinzaine de tables occupées , cela présage généralement une belle expérience !                         \n\nJe fus vraiment plus que bien accueilli par 2 charmantes serveuses qui m'annoncent que le restaurant est complet mais qu'elles vont me préparer la table d'hôtes.\n\nUne grande table rien que pour moi j'étais aux anges. Bref le repas commence, minestron de légumes et bisque de homard et gambas un délice.\nLe patron vient me voir pour me conseiller un petit blanc justement trouvé pour accompagner mon mon entrée ( n'hésitez pas à le demander il s'y connaît vraiment bien au vu des recommandations) \n\nLe plat arrive selle d'agneau, champignons, pomme de terres parfaitement assaisonnées et jus corsé un petit délice ! \nOn m'a dirigé vers un Bourgogne ( les rives de l'étang ) somptueux. \n\nUn moment vraiment agréable, un service excellent,  une cuisine recherchée et très bien exécutée .\n\nJe ne peux que vous le conseiller foncez y le midi comme le soir. \n\n", 5.0, '22', 'février', '2024', 'févr.', '2024', 'friends')
# (44, 1, 3, 'Restaurant Exceptionnel !', 'Une saint-Valentin inoubliable, une cuisine raffinée, nous avons passé un si bon moment dans ce restaurant  ! Le service est également exceptionnel !  A très vite, nous avons hâte de revenir !', 5.0, '15', 'février', '2024', 'févr.', '2024', 'couples')
# (45, 1, 6, 'A tester pour le plaisir des papilles', 'Agréable moment en couple où nous avons choisi le menu dégustation. Les plats sont très bons, raffinés et originaux dans le goût et les saveurs. Au niveau des quantités c’est ce qu’il faut nous ne sommes pas ressortis «\xa0trop plein\xa0». Bravo aux équipes en cuisine.\nSeuls petits bémols, les plats s’enchaînent assez vite, les tables sont très rapprochées (pas trop d’intimité)  et une des serveuses en salle est un peu «\xa0hautaine\xa0» et pourrait être un peu plus aimable dans la relation avec les clients.\nNous recommandons ce restaurant qui est à découvrir car nous avons fait une bonne découverte culinaire.', 4.0, '20', 'janvier', '2024', 'janv.', '2024', 'couples')
# (46, 1, 13, 'Voyage culinaire étonnant', 'Belle soirée avec le menu dégustation ( 2 entrées 2 plats et une dessert ).\nPas trop copieux ce qui permet de terminer sans être trop lourd \nService impeccable', 5.0, '17', 'janvier', '2024', 'janv.', '2024', 'couples')
# (47, 1, 1, 'Sympa et succulent !', 'Ce restaurant est très agréable, le service est rapide, et sympathique, et les plats sont délicieux et très bien présentés.\nA recommander !', 5.0, '16', 'janvier', '2024', 'janv.', '2024', 'couples')
# (48, 1, 23, 'Délicieux, sympathique et professionnel', 'Accueil et service très chaleureux et efficace. La salle est agréable et l’on s’y sent à son aise. Les plats sont délicats, originaux et pleins de saveurs. Les vins proposés en bouteille offrent un large choix et sont de qualité. Situé à 5 minutes du métro Croix-Rousse dans une petite rue tranquille. Parfait !', 5.0, '12', 'janvier', '2024', 'janv.', '2024', 'friends')
# (49, 1, 6, 'Très bon restaurant', "Très bon moment passé à l'aromatic, nous avons très bien mangé; et les équipes sont très sympas. les prix sont tout à fait corrects pour le menu que nous avons pris, nous vous recommandons cet endroit.", 5.0, '9', 'janvier', '2024', 'janv.', '2024', 'couples')
# (50, 1, 3, 'Top ', 'Nous avons passé un excellent moment, j’ai dîné avec ma mère. Les plats sont fins et originaux, les saveurs exquises, la bouteille de vin qu’on nous a recommandée allait parfaitement avec nos plats. \nLe service est juste le bon rythme \nTrès bonne expérience, je reviendrai !', 5.0, '6', 'janvier', '2024', 'janv.', '2024', 'family')
# (51, 1, 928, 'Parfait', 'Un restaurant que je voulais faire depuis bien longtemps ! Je n’aurais pas dû attendre autant ! L’accueil est chaleureux et irréprochable tout comme le service ! Les plats sont absolument tous excellents, soignés, et les associations sont parfaites ! On s’est régalés de la mise en bouche au dessert ! Restaurant qui mérite très largement ses notes, n’hésitez pas une seule seconde', 5.0, '6', 'janvier', '2024', 'janv.', '2024', 'friends')
# (52, 1, 1, 'AROMATICS UNE BELLE DECOUVERTE DE CUISINE CREATIVE ET GOUTEUSE ', 'TRES BON RESTAURANT UNE CUISINE CREATIVE AVEC DES METS DE QUALITE .            UN ACCUEIL CHALEUREUX ET PROFESSIONNEL.  UNE AMBIANCE COSY PAS TROP DE COUVERT .UNE BELLE DECOUVERTE NOUS AVONS PASSE UNE SOIREE TRES AGREABLE . ', 5.0, '5', 'janvier', '2024', 'janv.', '2024', 'family')
# (53, 1, 141, 'Un endroit à ne pas rater', 'Tout ce que l’on recherche aujourd’hui dans la restauration… des produits excellents, préparés avec soin, avec goût, des prix contenus, un véritable savoir-faire culinaire ! Bravo et merci. Ajoutons une carte des vins très bien faites à des prix extrêmement accessibles ! À faire de toute urgence ! Bravo', 5.0, '3', 'janvier', '2024', 'janv.', '2024', 'business')
# (54, 1, 26, 'Superbe', 'Superbe restaurant\nTous les plats sont délicieux et merveilleusement cuisinés. Le service est top et de bon conseil.\nNous avons dîné saumon, poisson,Saint Jacques dessert au chocolat et mont blanc.\nS était incroyable toutes ces saveurs.', 5.0, '27', 'décembre', '2023', 'déc.', '2023', 'couples')
# (55, 1, 546, 'Régalez vous', 'Un enchantement \nMes papilles frétillent encore \nUn mélange de saveur \nLe produit est au rdv et mis en valeur avec les condiments et sauces \nUn vrai régal \nOn peut y aller les yeux fermés', 5.0, '9', 'décembre', '2023', 'déc.', '2023', 'business')
# (56, 1, 14, 'Parfait de bout en bout', 'Encore une fois parfait, toute la table était unanime.\nJamais déçu \nMerci à toute l’équipe pour ce délicieux moment.\nÀ très bientôt', 5.0, '19', 'novembre', '2023', 'nov.', '2023', 'couples')
# (57, 1, 8, 'Raffiné et copieux ', 'Accueil agréable pour un repas raffiné et copieux.\nSeul (très) petit bémol, une fois que vous êtes assis, vous ne pouvez plus bouger quand vous êtes à certaines tables.\nMais,, nous recommandons fortement et nous reviendrons avec plaisir !\nApparemment, les menus changent chaque mois, donc pourquoi pas dès le mois prochain. ', 5.0, '18', 'novembre', '2023', 'nov.', '2023', 'friends')
# (58, 1, 1, 'Belle découverte ', 'Cuisine raffinée , quantité et qualité au rendez vous , serveuse souriante et efficace !\nA découvrir très vite pour ceux qui ne connaissent pas et bravo à l’équipe 🤗', 5.0, '15', 'novembre', '2023', 'nov.', '2023', 'couples')
# (59, 1, 25, 'A découvrir absolument ', 'Très belle découverte !!\nDes mets de qualité,  des saveurs incroyables. \nService très agréable,  carte bien travaillée permettant un menu avec 3 plats ou un menu dégustation surprise au grès du chef', 5.0, '10', 'novembre', '2023', 'nov.', '2023', 'couples')
# (60, 1, 18, 'Quiet good', 'Top \nSurtout la petite salle au fond.\n\nService un peu long en revanche et prix des st jacques pas donnés.\n\nEn revanche le global était top', 5.0, '4', 'novembre', '2023', 'nov.', '2023', 'family')
# (61, 1, 1, 'Très bien. ', 'Très bon restaurant . Accueil et service très agréables,  cuisine de qualité.  Juste les desserts un peu en dessous du reste.\nLe cadre soigné.  Quoi de plus?\nUn bon moment.', 4.0, '28', 'octobre', '2023', 'oct.', '2023', 'couples')
# (62, 1, 2, 'Un régal en bouche ', "Très bon accueil et super service tout le long du déjeuner. N'étant pas une grande connaisseuse des vins et de leurs accords, je me suis fait guider de l'entrée au dessert avec des recommandations qui se mariaient parfaitement avec les mets. Les plats sont réalisés avec finesse et on le ressent en bouche, un vrai régal ! Très bonne adresse, c'est certain nous y retournerons ! Un grand merci à la serveuse de notre table pour ces découvertes en vin et votre gentillesse. :) Bon courage pour la suite ! ", 5.0, '28', 'octobre', '2023', 'oct.', '2023', 'family')
# (63, 1, 12, 'Cuisine de qualité dans un lieu intimiste', 'Des mets de qualité avec un savoir faire de pro.Du pain aux couverts ,tout est bon et beau.\nUne excellente cuisine dans une petite salle un peu bruyante seul bémol.\nBon accueil également et service rapide pour un déjeuner.\nA recommander ', 4.0, '18', 'octobre', '2023', 'oct.', '2023', 'family')
# (64, 1, 141, 'Belle experience ! Bravo', 'Bravo pour cette excellente prestation.\nDes produits de grandes qualités, préparés de façon subtile, ce que nous voulons manger aujourd’hui ! Un service charmant, des jeunes filles d’un agréable commerce, souriantes , serviables et efficaces … vraiment une expérience de très grande qualité ! Merci pour cet excellent moment !', 5.0, '2', 'octobre', '2023', 'oct.', '2023', 'business')
# (65, 1, 2, 'Un restaurant que nous aimons faire découvrir à nos amis', 'Une Bonne table à la Croix Rousse,  un service attentionné et très agréable. Nous recommandons et reviendrons !', 5.0, '2', 'octobre', '2023', 'oct.', '2023', 'friends')
# (66, 1, 36, 'Des plats et vins délicieux !', 'Nous avons passé un moment convivial dans ce restaurant typique de La Croix Rousse.\nLes plats sont délicieux et la carte des vins est variée, ce qui nous a permis de goûter à différentes références que nous ne connaissions pas. L’équipe est souriante et attentionnée ! Cela faisait quelques mois que nous n’étions pas venus, nous n’attendrons plus aussi longtemps pour notre prochaine visite !', 5.0, '30', 'septembre', '2023', 'sept.', '2023', 'friends')
# (67, 1, 108, 'Un moment de bien-être', 'Très belle carte! Un vrai plaisir gustatif. Très bon accueil. Plats dignes d’un gastronomique. Belle carte des vins. Foie gras poêlé, quasi de veau tout était parfait', 5.0, '30', 'septembre', '2023', 'sept.', '2023', 'couples')
# (68, 1, 1, 'Totalement satisfait', 'Toujours aussi délicieux\nCapable de rebondir suite à des remarques. \nService parfait et chaleureux.\nUne des meilleurs table de la Croix rousse.', 5.0, '30', 'septembre', '2023', 'sept.', '2023', 'couples')
# (69, 1, 13, 'Excellent bistronomique à la Croix Rousse', "Soirée en couple pour fête d'anniversaire de mariage, nous avions pris le menu 3 plats, une assiette de jambon et une bouteille de vin. Nous avons été ravis par l'ensemble des plats de l'entrée au dessert. Service très sympathique et professionnel. Une excellente adresse où nous aurons le plaisir de revenir avec des amis.", 5.0, '24', 'septembre', '2023', 'sept.', '2023', 'couples')
# (70, 1, 16, 'A découvrir', 'Toujours très bien ! Bon accueil Petit restaurant très agréable dans un coin au calme de La Croix Rousse', 5.0, '7', 'septembre', '2023', 'sept.', '2023', 'friends')
# (71, 1, 5, 'Déjeuner fin et travaillé', 'Bon service\nIngrédients de qualité bien cuisinés\nUne carte variée\nLa truite gravelax est excellente\nLe cochon, fondant et en bonne quantité\nPour les sèches, parfaitement cuites, le maïs ne domine-t-il pas trop ?\nBref un moment agréable ', 4.0, '2', 'septembre', '2023', 'sept.', '2023', 'family')
# (72, 1, 36, 'Une bonne adresse sur la Croix Rousse', "Une très bonne soirée, un accueil avec le bon ton.\nLe service était au rdv.\nDans l'assiette, c'était parfait.\n\n", 5.0, '30', 'août', '2023', 'août', '2023', 'friends')
# (73, 1, 11, 'Service et plats qualitatifs', 'Très bon restaurant, lieu chaleureux, personnel accueillant et à l’écoute, plats original et délicieux. Je recommande !', 5.0, '26', 'août', '2023', 'août', '2023', 'couples')
# (74, 1, 14, 'A recommander on', 'Nous avons adoré ce restaurant. Tout d abord un accueil chaleureux, un service impeccable, rapide et efficace. Et dans l assiette, c était beau et bon : très belles associations de saveurs, originales et délicieuses. On reviendra avec plaisir !', 4.0, '25', 'août', '2023', 'août', '2023', 'couples')
# (75, 1, 1214, 'valeur sûre à la croix-rousse', "Troisième dîner à Aromatic. C'est indéniablement une valeur sûre ! Cuisine gouteuse et joli cadre. Mention spéciale pour le risotto et les desserts. Nous reviendrons ! ", 4.0, '25', 'août', '2023', 'sept.', '2022', 'couples')
# (76, 1, 11, 'Une équipe engagés', 'Très bonne expérience, le service et la prestation étaient de tres bon niveau .\nNous avons fait une remarque concernant un plat ou l’harrisa prenait le dessus \nL’équipe a été à l’écoute est tres engagée \nUne vrai harmonie règne dans la cuisine on voit que tout le monde tire à même corde \nUn vrai bon restaurant', 4.0, '20', 'août', '2023', 'août', '2023', 'friends')
# (77, 1, 4, "Très bon repas d'anniversaire", 'Repas de poisson (thon et encornet) très bon. Bon conseil pour le vin. \nPlats bien présentés et recettes originales. Exemple: Tentacule d’encornet snackée, courgette rôtie et en caviar, sauce fromage blanc au cumin, menthe et pommes granny smith\nCadre et personnel agréable', 5.0, '17', 'août', '2023', 'août', '2023', 'couples')
# (78, 1, 5, 'Un très beau moment', 'Restaurant très agréable, très bonne cuisine (gaspacho avec sorbet de scamorza fumée à se damner). \nService excellent, de très bon conseil, avec sourire et bonne humeur. Portions généreuses à mon sens.\nUne belle adresse.', 4.0, '17', 'août', '2023', 'août', '2023', 'couples')
# (79, 1, 7, 'Une expérience fantastique', "Nous avons choisi le menu dégustation. Tous les plats étaient excellents, originaux et en accord avec la saisonnalité. Comme vin, nous avons pris un Bourgogne Hautes-Cotes De Nuits servi à la bonne température. Le personnel était sympathique et le prix convenable. J'espère revenir bientôt. Mes compliments.", 5.0, '2', 'août', '2023', 'juil.', '2023', 'couples')
# (80, 1, 3, 'Excellent restaurant quartier Croix Rousse.', 'Très belle expérience : menu du jour abordable (24 €) avec des plats originaux et d\'une grande finesse, excellent St Joseph blanc. Si nous étions lyonnais, nous en ferions volontiers notre "cantine".', 5.0, '25', 'juillet', '2023', 'juil.', '2023', 'family')
# (81, 1, 2, 'Belle expérience', "Service attentionné et courtois. Environnement confortable. Cuisine toujours excellente. J'y ai mangé cinq fois ces deux dernières années : carte toujours variée, grande attention portée aux matières premières, préparation légère et équilibrée. Alliance parfaite de la tradition et de l'innovation. Excellence particulière pour les desserts. Bonne carte des vins, également au verre", 5.0, '16', 'juillet', '2023', 'juil.', '2023', 'couples')
# (82, 1, 107, 'A revoir ...', "Vraiment dommage  que ce passe-t-il ?\nAlors même que le restaurant n'était pas plein ,\nUne attente pas possible, \nDommage qu'il y a une baisse , de service et de qualité .\nUn changement étonnant !!!!!\n", 3.0, '12', 'juillet', '2023', 'juil.', '2023', 'business')
# (83, 1, 1, 'Très belle soirée', "Quelle belle soirée. Tout était délicieux de l'accueil à l'assiette. Nous étions 9 adultes et nous avons été installés dans une belle salle, seuls et nous pouvions parler, rire sans gêner les autres tables. Très gentille attention que nous avons vraiment apprécié.", 5.0, '10', 'juillet', '2023', 'juil.', '2023', 'friends')
# (84, 1, 374, 'Une très belle cuisine légère, goutue et colorée', 'Une cuisine revisitant les recettes que l’on croyait connaître comme ces sardines de Galice qui font redécouvrir le vrai goût de la sardine, le veau qui fait penser au Vitello tonnato. \nAccueil par ailleurs tres sympathique, une terrasse où un intérieur également agréables.\nUne belle soirée dans un des meilleurs restaurants de Lyon et…pour un prix tres raisonnable…', 5.0, '9', 'juillet', '2023', 'juil.', '2023', 'couples')
# (85, 1, 12, 'Très belle expérience culinaire', "Nous avons passé un très bon moment gustatif avec des plats élégants et raffinés ,très bien équilibrés .\nMention particulière à la directrice de salle et un grand merci pour l'attention que vous nous avez porté", 5.0, '8', 'juillet', '2023', 'juil.', '2023', 'couples')
# (86, 1, 5, 'Endroit à éviter !', 'À éviter absolument ! Service plus que médiocre, on aurait dit qu’on embêtait le personnel qui était très peu aimable lors de la prise des commandes et des apéritifs. Pour la cuisson de la viande les serveurs nous ont demandé «\xa0saignant ça vous va ?\xa0» plutôt que de demander à chacun la cuisson désirée, tout cela pour nous rapporter finalement des plats cuits à point. Je suis peut-être venu un «\xa0mauvais jour\xa0»pour le restaurant mais il n’empêche que le client est censé être privilégié, c’est quand mème nous qui avons payé à la fin et le rapport qualité-prix était loin d’être rentable. Bref, endroit à éviter.', 1.0, '5', 'juillet', '2023', 'juin', '2023', 'family')
# (87, 1, 2, 'RV parfait', "menu équilibré (un petit bémol : un de 2 desserts un peu trop sucré pour quelqu'un qui en consomme peu ou pas d'habitude)\nservice impeccable", 5.0, '1', 'juillet', '2023', 'juil.', '2023', 'family')
# (88, 1, 1, 'Délicieux et créatif ', "Délicieux et créatif, de l'entrée au dessert. Une carte courte mais inspirée, avec des produits de saison.", 5.0, '25', 'juin', '2023', 'juin', '2023', 'friends')
# (89, 1, 5, 'Très bonne adresse : cuisine raffinée et accueil très chaleureux', 'Très bonne adresse ; la cuisine est raffinée , le service est au top : l’accueil , les explications sur les plats , le sourire !\nNous avons pris le menu dégustation, qui permet de goûter beaucoup de plats, sans être trop lourd car les quantités sont très bien proportionnées.\nBravo !', 5.0, '16', 'juin', '2023', 'juin', '2023', 'family')
# (90, 1, 36, 'Bonne cuisine, service perfectible', 'Venus un soir en couple pour fêter notre anniversaire, nous avons bien été accueillis, l\'apéritif maison du moment était bon, à ceci prêt que 2 minutes après arrivaient déjà nos entrées "désolé c\'est sorti un peu vite". Un peu perturbés de ne pouvoir prendre le temps.. avec un apéritif dont le goût (limoncello) ne collait pas du tout aux saveurs des plats et cela nous embêtait de rajouter du vin sans terminer l\'apéritif... Les gnocchis et le bœuf angus étaient tout simplement divins, nous nous sommes vraiment régalés, l\'exécution était parfaite. Nous avons moins apprécié la tarte aux fraises/amandes/safran, retrouvant peu de saveur dans la glace safran, mais c\'est affaire de goût, le travail de recherche était là. \nNous avons été débarrassés un peu précipitamment, sans que la personne se rende compte avoir versé le jus de l\'assiette sur mon pantalon (forcément un jus assez gras...). \nNous restons sur une relativement bonne expérience. Mais dommage que la qualité des mets soit grevée par le  timing et le service.', 3.0, '10', 'juin', '2023', 'juin', '2023', 'couples')
# (91, 1, 3, 'Excellente soirée, qualité accueil et de la restauration', 'Etablissement très agréable, gastronomie originale et savoureuse.\nTout était conforme à nos attentes', 4.0, '7', 'juin', '2023', 'juin', '2023', 'couples')
# (92, 1, 1049, 'Excellent restaurant', 'Accueil et service très sympas et efficaces.\nLa carte change tous les mois et même si elle est courte, il y en a pour tous les goûts. \nTout est excellent. \nBelle carte de vins.\nLes formules menus permettent de s’en sortir pour un prix raisonnable.\nBref belle découverte; et puis nous étions tellement heureux de pouvoir tester car ce restaurant affiche souvent complet !', 5.0, '28', 'mai', '2023', 'mai', '2023', 'couples')
# (93, 1, 24, 'À découvrir très vite !', 'Dîner en tête à tête en terrasse.\nDe la mise en bouche au dessert, nous nous sommes régalés!\nNous avions choisi le menu en 5 services, à la discrétion du chef.\nUne belle adresse classe et cool hautement recommandée !', 5.0, '28', 'mai', '2023', 'mai', '2023', 'couples')
# (94, 1, 1, 'Belle découverte', 'Des produits de qualité parfaitement cuisinés et bien accompagnés. Service simple et efficace, une belle découverte ! ', 5.0, '24', 'mai', '2023', 'mai', '2023', 'friends')
# (95, 1, 223, 'Nouveauté et fraîcheur ', "Une cuisine toujours aussi savoureuse et d'une grande fraîcheur. Quel bon moment ! Une adresse incontournable à Lyon. ", 5.0, '17', 'mai', '2023', 'mai', '2023', 'couples')
# (96, 1, 9, 'Délicieux et chaleureux !', 'Notre dîner était parfait. Des plats fins, parfumés et créatifs, servis par une serveuse drôle et attentionnée, qui galope, qui galope…\nAvec en prime, un très bon rapport qualité/prix.\nLes gaulées 5000 reviendront !', 5.0, '16', 'mai', '2023', 'mai', '2023', 'friends')
# (97, 1, 2, 'excellent!', "C'était parfait comme d'habitude...\nLa cuisine est toujours très qualitative, tant en bouche qu'au visuel, le service est agréable et efficace.\nNous reviendrons encore...", 5.0, '13', 'mai', '2023', 'mai', '2023', 'none')
# (98, 1, 55, "C'est trop bon !", "Seconde visite : encore mieux que la première fois ! Personnel charmant et attentionné qui sait nous mettre à l'aise. Plats divins ! Beaucoup de finesse, de subtilité et du goût avec des produits de qualité si bien cuisinés : MERCI !!", 5.0, '6', 'mai', '2023', 'mai', '2023', 'business')
# (99, 1, 353, 'Excellent restaurant gastronomique. Cuisine raffinée,  assemblage des saveurs très goutu et excellent. Service efficace', 'Excellent restaurant gastronomique, cuisine très goutue et joliment présentée. Assemblage des saveurs exceptionnel. Bon choix de vins', 5.0, '6', 'mai', '2023', 'mai', '2023', 'family')
# (100, 1, 102, "Mais ce n'est pas un bistro", "Accueil très sympa, salle plutôt petite, mais bonne organisation pour que l'on ne se gêne pas. Service au top, pas trop rapide pas lent du tout, et un repas délicieux. Une présentation digne des meilleurs, des saveurs bien dosées, toute les assiettes repartent vides!\nCertainement c'est bistronomique, mais assurément c'est gastronomique.\nNous sommes très satisfaits.", 5.0, '3', 'mai', '2023', 'mai', '2023', 'friends')
# (101, 1, 2, 'Restaurant à retenir', "Le lieu est agréable et l'équipe très souriante et de bon conseil. Nous avons particulièrement apprécié en entrée les ravioles au homard  et le dessert au pain perdu. Le plat principale Maigre de Corse méritait d'être un peu plus relevé. ", 5.0, '30', 'avril', '2023', 'avr.', '2023', 'none')
# (102, 1, 2, 'Dîner en couple', 'Un moment délicieux. Les serveuses ont su nous accompagner avec sourire et sympathie . Le dîner était parfait.', 5.0, '29', 'avril', '2023', 'avr.', '2023', 'couples')
# (103, 1, 2, 'Retour expérience', 'Très bonne adresse avec un très bon accueil  \nLes plats étaient tous très fins copieux avec un large choix ', 5.0, '15', 'avril', '2023', 'avr.', '2023', 'none')
# (104, 1, 1, 'Excellent', 'Menu dégustation excellent et vins très bien conseillés. Nous reviendrons avec grand plaisir et recommanderons ce restaurant.', 5.0, '14', 'avril', '2023', 'mars', '2023', 'couples')
# (105, 1, 1, 'Je recommande!!!!', 'Un service au Top avec sourire et écoute,de belles et bonnes assiettes pleines de saveurs!!!!Bravissimo!!!!\nA refaire!!!!!', 5.0, '14', 'avril', '2023', 'avr.', '2023', 'couples')
# (106, 1, 51, 'Exceptionnel', 'Exceptionnel !\nDe l’amuse-bouche au dessert, un festival de saveurs avec des accords originaux et toujours bien dosés. Les ravioles de homard étaient à tomber! A refaire absolument !', 5.0, '4', 'avril', '2023', 'avr.', '2023', 'family')
# (107, 1, 26, 'Un délice ', "Un pur délice!\nDe l'entrée au plat chaud en passant par le fromage somptueux qui lui aussi est cuisiné pour finir par un dessert à tomber. ", 5.0, '4', 'avril', '2023', 'avr.', '2023', 'family')
# (108, 1, 8, 'Cadre très sympa, personnel très efficace et chaleureux et repas délicieux !', 'Super ! Nous reviendrons ! Nous avons passé un excellent moment ! Nous avons très bien mangé et nous avons été très bien accueilli !', 5.0, '1', 'avril', '2023', 'mars', '2023', 'couples')
# (109, 1, 11, 'Excellente soirée !', "C'était comme d'habitude excellent ! Très bons produits, mélanges exquis , saveurs et sensations en bouche fort plaisantes .Service agréable ! \n", 5.0, '31', 'mars', '2023', 'mars', '2023', 'friends')
# (110, 1, 6, 'Allez-y ', "Une soirée en couple sous les plus beaux hospices. Une carte réduite mais on n'est pas contre. C'est généralement un signe de qualité. Très bonne cuisine pleine de saveurs. Une jeune équipe qui mérite toute notre estime surtout en cette période difficile pour elle. Mention particulière au chef qui nous  a permis de nous évader avec ses senteurs méditerranéennes: un carpaccio de bar de Corse : une merveille (les papilles encore en ebullition)  suivi d'un carré d'agnbeau cuit à la perfection et qui sentait bon le midi. L'accompagnement était également à la hauteur. Les vins étaient parfaitement bien choisis. Allez leur rendre visite, vous ne serez pas déçus. \nNous on y retournera. \nSeul petit bémol: le chauffage qui mériterait d'être augmenté. ", 5.0, '29', 'mars', '2023', 'mars', '2023', 'couples')
# (111, 1, 14, 'Super', "Menu dégustation très bon, service soigné, bon conseil vin. 2ème fois que j'y vais et je recommande toujours autant.", 5.0, '24', 'mars', '2023', 'mars', '2023', 'couples')
# (112, 1, 1, 'Belle expérience ', 'Endroit sympa. Cuisine agréable et originale. Bon produit. Service dans un bon timing. Choix des vins intéressant ', 4.0, '24', 'mars', '2023', 'mars', '2023', 'none')
# (113, 1, 11, 'Incroyable', 'Mets excellents de l’apéritif jusqu’aux desserts, cuisine originale, raffinée et le service est de qualité.', 5.0, '17', 'mars', '2023', 'mars', '2023', 'family')
# (114, 1, 18, 'Excellente adresse', 'Nous avions réservé suite aux bons avis lu sur Google, et nous n’avons clairement pas été déçus !\nDe l’entrée au dessert tout était excellent 👌 \nLa prochaine fois que nous reviendrons à Lyon, nous y retournerons sans faute !', 5.0, '25', 'février', '2023', 'févr.', '2023', 'couples')
# (115, 1, 1, 'Excellent', "Le repas à l'aveugle est super ! On ne choisit pas les plats, mais tout est excellent. Dommage qu'il n'y ait pas une option véggie ... Mais autrement super accueil, bon vin et produit de qualité.", 4.0, '22', 'février', '2023', 'févr.', '2023', 'none')
# (116, 1, 1, 'Excellent Restaurant', 'Personnel très aimable\nEntrée excellente\nPlat du jour bien\n\nTrès bon rapport qualité/prix\n\nCadre réconfortant', 5.0, '22', 'février', '2023', 'févr.', '2023', 'none')
# (117, 1, 6, 'Un sans faute', 'C’est un sans faute, un melange de saveurs exceptionnel, le service parfait également.\nJuste un bémol La deco du resto pas à mon goût mais sinon 10/10', 5.0, '16', 'février', '2023', 'févr.', '2023', 'couples')
# (118, 1, 17, 'Une belle découverte.', 'Excellent restaurant. Des plats savoureux avec des notes justes. Un service sympathique et professionnel. Une belle adresse à découvrir.', 5.0, '4', 'février', '2023', 'févr.', '2023', 'family')
# (119, 1, 70, 'Super!', 'Superbe découverte a la croix-rousse.  Belle carte de vin. Un excellent repas avec de bkns conseils des serveurs! Raserver imperativement. On y reviendra!', 5.0, '4', 'février', '2023', 'févr.', '2023', 'couples')
# (120, 1, 3, 'Un service qui fait de l’ombre à la qualité des mets.', 'Les plats sont délicieux, la viande, les poissons sont formidables et certaines recettes sont très inventives. Nous avons passé un bon moment. \nDommage que le service soit aussi bâclé. On a un peu l’impression que l’important est de ne pas fermer trop tard…\nDu coup, une prise de commande (très) speed, une présentation des plats à 2000 à l’heure et un accueil qui, sans être désagréable, n’est pas très chaleureux ni très enthousiaste.\n\nNous n’avons pas été mal reçus, simplement nous aurions aimé nous sentir plus accueillis. Avec un petit effort sur le service, ce restaurant serait sans doute une adresse de référence.', 3.0, '1', 'février', '2023', 'févr.', '2023', 'friends')
# (121, 1, 11, 'Adresse à retenir quartier Croix-Rousse', 'cuisine fine et inventive; service professionnel et agréable; très bon rapport qualité/prix, notamment pour le menu du jour', 5.0, '25', 'janvier', '2023', 'janv.', '2023', 'none')
# (122, 1, 3, 'A réserver sur Lyon. ', "Équipe jeune et dynamique. L'endroit est cosy et le service rapide. Les assiettes sont superbes visuellement. Les mélanges étonnent par leurs nouveautés. Dîner parfait en 3 services. Il existe le menu en 5 services et le tout à des tarifs très corrects. Mérite une étoile très bientot. ", 5.0, '20', 'janvier', '2023', 'janv.', '2023', 'couples')
# (123, 1, 2, 'Un délice', 'Comme à chacune de mes visites, le service est rapide, prévenant, agréable, les mets sont délicieux et raffinés, à des prix abordables et avec un personnel ainsi qu’un chef d’établissement, commerçant, poli et respectueux.\nLa qualité de l’aromatic n’est plus à prouver, je ne peux que recommander et revenir de manière régulière.', 5.0, '19', 'janvier', '2023', 'janv.', '2023', 'friends')
# (124, 1, 5, 'Papilles heureuses !', 'Cuisine fine et inventive, carte des vins intéressante. Le service est attentionné. Seule la décoration est peut-être à réinterroger.', 5.0, '15', 'janvier', '2023', 'janv.', '2023', 'couples')
# (125, 1, 15, 'Notre coup de coeur', 'Nous sommes des fidèles de ce restaurant car nous n\'avons jamais trouvé un meilleur rapport qualité/prix sur Lyon et notamment à la Croix-Rousse (Lyon 4).\nTous les plats sont cuisinés avec délicatesse, les saveurs sont juste "à tomber" tellement les cuisiniers savent mettre le produit en valeur. \nExcellente carte des vins. \nAccueil toujours sympathique et chaleureux. \nService excellent.\nNous le faisons découvrir régulièrement à des amis qui sont tous unanimes sur  cette belle surprise.\nContinuez à nous régaler !', 5.0, '15', 'janvier', '2023', 'janv.', '2023', 'none')
# (126, 1, 24, 'Cuisine raffinée et inventive', 'Ce restaurant mérite vraiment le Bib Gourmand que lui a octroyé le guide Michelin.\nLa jeune équipe en cuisine propose une carte particulièrement inventive et raffinée, préparée avec de très bons produits servis avec professionnalisme. Tant au niveau des associations de saveurs que de la présentation des plats, le menu à la carte que nous avons choisi a été un véritable régal.', 5.0, '11', 'janvier', '2023', 'janv.', '2023', 'none')
# (127, 1, 1, 'Un diner parfait', "De la mise en bouche au dessert, tout était absolument parfait ! Les associations de saveurs, les cuissons, le salé comme le sucré, nous avons tout adoré !\n ( si les portions peuvent paraître petite pour certains, c'est uniquement parce que c'est tellement délicieux qu'on pourrait en manger jusqu'au bout de la nuit :)\nLes serveurs sont adorables et très attentionnés.\nVraiment une très belle découvert !", 5.0, '11', 'janvier', '2023', 'janv.', '2023', 'none')
# (128, 1, 4, 'Soirée parfaite', "Nous étions 14 convives réunis pour un anniversaire et notre soirée a fait l'unanimité. C'était parfait. D'abord la cuisine, les plats sont savoureux, fin et inventifs mais les portions un peu juste si vous êtes un gros mangeur. En ce qui concerne le service c'est un sans faute, souriant, prévenant, de bon conseil pour le vin. Une excellente adresse avec un très bon rapport qualité/prix que je conseille.", 5.0, '9', 'janvier', '2023', 'janv.', '2023', 'none')
# (129, 1, 1563, 'Bon mais pas assez copieux', 'Bistrot de qualité.\nPlats très goûteux fait maison mais dommage,\nPas assez copieux pour nous.\nService impersonnel.\nBilan mitigé.\nNous avions encore faim en sortant.\nNous ne reviendrons pas.', 3.0, '23', 'décembre', '2022', 'déc.', '2022', 'couples')
# (130, 1, 1, "Un peu déçue par rapport à d'habitude", "J'ai l'habitude de venir dans cet établissement que j'apprécie et que je recommande souvent, mais peut-être sommes-nous tombées le mauvais jour : plats tièdes, service pas au top (pour le vin notamment) et manque de saveurs et de finesses dans les plats...", 3.0, '10', 'décembre', '2022', 'déc.', '2022', 'none')
# (131, 1, 2, 'Un excellent moment', 'Très bonne cuisine, joli cadre, personnel charmant et accueillant, bon rapport qualité prix.Une excellente adresse', 5.0, '8', 'décembre', '2022', 'déc.', '2022', 'family')
# (132, 1, 2, 'Sublime cuisine,joli cadre,équipe attentionnée et performante . A découvrir à tout prix.', 'Excellent dîner d’anniversaire grâce à l’Aromatic. Une cuisine aux saveurs subtiles, des plats revisités très réussis et un service parfait Atmosphère agréable. Un sans faute .                     Une adresse à conserver.', 5.0, '3', 'décembre', '2022', 'nov.', '2022', 'family')
# (133, 1, 1, 'Les ingrédients d une bonne soirée', 'Les plats sont très bons, le personnel très accueillant. Un très bon moment gustatif et convivial pour un prix raisonnable. Je conseille fortement !', 5.0, '27', 'novembre', '2022', 'nov.', '2022', 'couples')
# (134, 1, 3, 'Belle adresse à Croix Rousse', 'Cadre tout mignon\nÉquipe très sympatique\nCuisine savoureuse\nÀ faire et à refaire la carte change tous les mois\nBravo !', 5.0, '26', 'novembre', '2022', 'nov.', '2022', 'couples')
# (135, 1, 13, 'Adresse qui mérite à être connue !', 'Superbe découverte!\nCuisine française bistronomique sans aucune fausse note du début à la fin. Un régale! \nAdresse qui mérite à être connue.', 5.0, '18', 'novembre', '2022', 'nov.', '2022', 'couples')
# (136, 1, 4, "Repas d'anniversaire", 'Excellente cuisine,des saveurs et des assaisonnements fins et bien choisis un accueil et service aimables et efficaces', 5.0, '12', 'novembre', '2022', 'nov.', '2022', 'family')
# (137, 1, 17, 'Excellent ', "Bientôt 5 ans que nous avons découvert ce restaurant et toujours un plaisir d'y retourner. L'assurance d'un excellent moment et d'une cuisine au top ! Encore merci...", 5.0, '23', 'octobre', '2022', 'oct.', '2022', 'couples')
# (138, 1, 1, 'Parfait resturant à Lyon', 'Très bonne adresse, je recommande\nservice et accueil impeccable, belle carte et pratique pour les végétariens', 5.0, '10', 'octobre', '2022', 'sept.', '2022', 'none')
# (139, 1, 3607, 'Hmmmm !!..BIEN  et BON !!👍😘', 'Une très bonne soirée dans un jolie cadre. Les serveurs sont Top !!👍agréables et de bon conseil. Les plats sont gouteux et bien présentés  \nEt pour finir ... dégustation de digestifs 🍷🍷chartreuse !! Hmmmm.', 5.0, '6', 'octobre', '2022', 'oct.', '2022', 'business')
# (140, 1, 1, 'super', 'super resto conseillé par des amis nous avons vraiment adoré. plats de saison et très bien cuisinés. merci pour ce bon moment.', 5.0, '3', 'octobre', '2022', 'sept.', '2022', 'none')
# ...
# (8198, 9, 38, 'Un merveilleux établissement traditionnel - Buchon', "Cuisine fantastique, chaleureuse d'une très avenant. Le menu ophtions en clair et s'amuser. Une très peu français n'a pas posé problème. La nourriture et le service étaient excellents. Nous avons vraiment apprécié discuter avec les autres clients. Très bon rapport qualité/prix.", 5.0, '19', 'octobre', '2016', 'oct.', '2016', 'couples')
# (8199, 9, 148, "Le meilleur repas et le sens de l'hospitalité de France", "L'hôtel était complet pour le week-end mais nous avons réussi à nous élégants pour le déjeuner le samedi. L'endroit était très animé quand nous sommes arrivés, donc beaucoup de gens du coin et des rires. Nous avons été accueillis par le propriétaire qui nous a offert un verre de vin offert gracieusement en attendant que notre table se libère. Il n'y a pas un menu. Le propriétaire nous a expliqué les plats qu'il y en avait pour la journée. Nous avons pris un saumon et 50-70 escargots, qui ont été tous les deux délicieux. Venir manger de bœuf joue du porc et rentrer à l'hôtel et c'était très lent et avaient diminué les os. La nourriture était exceptionnelle et le propriétaire était très amusant de prendre part les mains et animaux pour expliquer les plats. 2. A ce jour, donc nous avons essayé de participer aux activités du bon anniversaire des chansons. Une bouteille de vin et une légère touche a été apporté pour l'un et un gâteau dans l'autre. Une atmosphère familiale. Après le déjeuner pris parce que c'était la fin de l'après-midi pour se préparer pour le repas du soir la propriétaire a invité tout le monde derrière le restaurant, le musée d'impression est pour un peu d'histoire leçon. Il se trouve. L'un des clients a traduit tout pour nous. C'était un lieu unique et spécial. A ne pas manquer. Assurez-vous de réserver à l'avance ! Prix très raisonnable.", 5.0, '18', 'septembre', '2016', 'sept.', '2016', 'couples')
# (8200, 9, 281, 'Vous devez y aller !', "On nous a recommandé le restaurant par un local wine bar propriétaire sinon nous n'aurions jamais pensé pour vous. L'entrée se fait par une allée après la cuisine où l'ambiance était très décontractée et gai. Excellents repas Lyonais d'un restaurant qui a été construit il y a 50 ans. À ne pas manquer.", 5.0, '24', 'juillet', '2016', 'juil.', '2016', 'none')
# (8201, 9, 42, 'Riches et copieuse cuisine française', "Pas terrible et cher, le bouchon dans le 1 er arrondissement, c'est tout simplement fantastique. Le menu est établie en français, mais le chef se trouve en bas, et explique tout ce qui est en anglais. 3) et une carafe de vin coûte environ 30 EUR. La nourriture est copieuse, pleine de saveurs et d'une maison. Les portions sont copieuses. Le quenelle étouffée et fesse le cochon étaient incroyables. Le service est chaleureux, amical et avec un petit peu l'humour en prime. Beaucoup mieux que n'importe quel des endroits moins on trouve couramment à Paris.", 5.0, '17', 'juillet', '2016', 'juil.', '2016', 'solo')
# (8202, 9, 298, 'Authentique cuisine lyonnaise.', "C'est un établissement adorable pour prendre authentique cuisine lyonnaise dans un bâtiment historique et espace. L'atmosphère est très attrayante. Le chef est située au bout de vous expliquer le menu avec une touche d'humour.\n\nNous avons commandé le jarret de porcelet au Foin & joues de porc. Le porc les plats étaient bien préparés. J'ai particulièrement apprécié la crème des pommes de terre et sauce au plus.\n\nPour le dessert que nous avions la mousse au chocolat, doux, moelleux et crème.\n\nLe restaurant est petit mais le service est très agréable.", 5.0, '22', 'juin', '2016', 'juin', '2016', 'friends')
# (8203, 9, 14, 'La nourriture est bonne et le personnel sympa', "La cuisine est délicieuse, le vin est bon, le personnel est sympa. Je recommande vivement ce restaurant. J'ai eu un déjeuner là-bas. J'y suis allée sans avoir un restaurant. Le propriétaire et le chef a expliqué tous les plats du menu anglais. J'ai eu une salade aux champignons sauvages, du poisson quenelle, vin blanc et crème brulée en dessert et café. Tout était vraiment délicieux. J'ai été vraiment rassasiés. J'ai payé 27 euros au total. J'ai aimé le fait que si l'ambiance qui y règne est sans prétention, les tables sont assez proche l'un après l'autre et vous êtes susceptible d'avoir des conversations avec les autres clients.", 5.0, '12', 'juin', '2016', 'juin', '2016', 'solo')
# (8204, 9, 9, 'Très bon service, délicieux restaurant !', "Nous avons fait une réservation en ligne (ce qui est essentiel de réserver) pour le déjeuner et nous sommes arrivés plus tôt que prévu, ce n'était pas grave et nous avons été accueillis chaleureusement par le personnel sympathique et on nous a donné une table.\n\nLuc le boulanger s'asseoir avec nous pour discuter avec les plats dans le français et l'anglais, avec une belle ambiance et fantastique nous a été recommandé.\n\nLa nourriture était délicieuse, l'atmosphère était agréable et c'était un excellent séjour!", 5.0, '21', 'avril', '2016', 'avr.', '2016', 'couples')
# (8205, 9, 3, 'Hôte incroyable !', "J'ai trouvé ce restaurant en voyage et nous avons donc décidé de réserver uniquement à Lyon dans le cadre d'une nuit. Nous n'avons pas été déçus ! Nous avons été accueillis par le propriétaire qui nous donner un coup de main pour chaque tableau en ce qui me concerne, pour expliquer le menu et divertir ses clients. Nous avons été très bien accueillis et on nous a donné une visite guidée de la région en dehors du restaurant et une explication que les tunnels ci-dessous ont été utilisés par les Français la résistance pendant la seconde guerre mondiale.\nLa nourriture était traditionnel et bons, très abordables, mais c'était l'ambiance du restaurant a restaurant qui est excellent pour nous.", 5.0, '10', 'avril', '2016', 'avr.', '2016', 'family')
# (8206, 9, 281, "Vit jusqu'à la Catégorie", "C'était un très bon choix. L'entrée est un peu étrange, vous allez dans une porte sur le côté dans ce qui ressemble à l'entrée d'un immeuble d'appartements. Les réservations sont un must. Anglais n'était pas un problème. Les personnes dans le restaurant étaient très sympa - ils nous ont même offert une certaine pate de lapin à essayer. Je suis heureux qu'ils l'ont fait. Pour la qualité de la nourriture que vous obtenez, le prix est très raisonnable par rapport aux normes des États-Unis.", 5.0, '13', 'mars', '2016', 'mars', '2016', 'none')
# (8207, 9, 40, 'Oh mon ...', "Excellent service : le personnel est serviable, la propriétaire, prend le temps de vous parler et évidemment aime partager sa nourriture.\nLa nourriture est à tomber par terre, vraiment. Et n'oubliez pas d'être ouverts: mon ami avait cerveau d'agneau pour main et c'était délicieux !\nLes prix sont vraiment raisonnables.\nAllez-y et ont une excellente soirée !", 5.0, '11', 'octobre', '2015', 'oct.', '2015', 'couples')
# (8208, 9, 30, 'Le Bouchon traditionnel', "Nous avons dîné ici hier soir et nous avons passé un très bon repas et un bon moment. Le propriétaire était très cordial et amusant. Les plats étaient ce que j'appelerais super plats maison française. La facture totale pour 3 personnes était 94 euros avec deux bouteilles de vin de la maison. Le propriétaire nous a emmenés pour une visite et une histoire des Traboules derrière le restaurant. Je recommande cet hôtel pour le dîner.", 5.0, '10', 'octobre', '2015', 'oct.', '2015', 'friends')
# (8209, 9, 4, 'Lyon une expérience authentique ... le bouchon !', 'Nous avons été à ce restaurant plusieurs fois déjà, et le seul mot que nous pouvons utiliser pour décrire « Le Musée" est: c\'est merveilleux ! Si vous êtes à la recherche d\'une expérience culinaire authentique de Lyon, puis continuez tout droit vers le musée. L\'ambiance est 100% lyonnais, le personnel est super sympa, et la nourriture est délicieuse. Qui plus est, le restaurant est un excellent rapport qualité-prix. Vous ne serez pas déçu ... amener votre appétit.', 5.0, '30', 'juin', '2015', 'juin', '2015', 'friends')
# (8210, 9, 35, 'La meilleure expérience à Lyon', "Nous avons passé une nuit merveilleuse ! J'ai mangé escargots pour la première fois\net c'était vraiment délicieux! J'ai aimé\ntout ce que j'ai goûté. Le propriétaire était très sympathique et ... Mais je ne vais pas vous gâcher la surprise. Un endroit incontournable de Lyon", 5.0, '20', 'mai', '2015', 'mai', '2015', 'friends')
# (8211, 9, 63, 'Un bel endroit sympathique', "Assurez-vous d'avoir un niveau de base ne parle pas bien français quand vous visitez cet endroit. Sinon, vous finirez par comme moi ... se déplacer beaucoup de surprises.\n\nLe propriétaire a essayé très difficile à expliquer le menu pour nous, et je me suis senti vraiment désolé pour les dérangions. Mais nous avons réussi à faire ce que nous voulons, et les plats sont fabuleux.\n\nLa je notre réservation par e-mail, j'ai écrit en français que le dîner était pour célébrer notre anniversaire de mariage. Et le propriétaire est très gentil et nous a donné un peu de surprise comme une fête.\n\nC'était un très bon souvenir. Pas seulement à cause de la nourriture, mais aussi des gens et l'ambiance. Hautement recommandé.", 5.0, '27', 'septembre', '2014', 'août', '2014', 'couples')
# (8212, 9, 8, 'Super Lyon bouchon', "Nous avons beaucoup apprécié la nourriture et l'expérience.\nLyon est une ville superbe et nous reviendrons sans aucun doute à ce restaurant lors de notre prochaine visite.", 4.0, '29', 'mai', '2014', 'avr.', '2014', 'family')
# (8213, 9, 16, "L'un des meilleurs bouchons à Lyon", "Nourriture était fantastique, très bonne ambiance. Le tout dans un bâtiment du 16ème siècle à côté du musée de l'impression.", 4.0, '27', 'mai', '2014', 'févr.', '2014', 'friends')
# (8214, 9, 429, 'Fabuleux Bouchon', "Ce qu'un petit restaurant incroyable. C'était plein de gens, nous étions les seuls touristes, toujours un bon signe. Le patron samedi avec nous et nous a dit que le menu et vraiment l'air de soin que nous devrions apprécier sa nourriture. C'était merveilleux, surtout les quenelles de brochet. Un très bon repas et une salle à manger très différente expérience, très local et amusant.", 5.0, '5', 'mars', '2014', 'janv.', '2014', 'friends')
# (8215, 9, 94, 'Nuit fantastique', "Ce n'est pas seulement la nourriture merveilleuse ... c'est l'atmosphère, le personnel, les autres responsables et le propriétaire. Vous êtes accueilli et occupé toute la nuit. C'est un super endroit pour passer un bon séjour à la française et à ne pas manquer ! C'est petit, confortable et respire la vie française - j'ai adoré chaque instant!", 5.0, '20', 'février', '2014', 'févr.', '2014', 'couples')
# (8216, 9, 85, 'La nourriture est excellente.', "Juste commander leur nourriture traditionnelle.. Il est petit, agréable et charmant. Le propriétaire va s'asseoir avec vous et vous expliquer le menu. L'un des doit aller à Lyon.\n\nRéservation est un must. Assurez-vous que vous appelez quelques jours à l'avance pour réserver une place. Ils sont toujours complet !", 4.0, '15', 'décembre', '2013', 'août', '2013', 'solo')
# (8217, 9, 10, 'Absolument merveilleux', "J'ai passé quelques jours à Lyon avec ma femme et un autre 2 couples. Basé sur les excellents commentaires sur Tripadvisor nous avons réservé le musée pour notre dernière nuit à Lyon. Nous n'avons pas été déçus, nous avons eu le meilleur repas de loin sur notre voyage. Nous avons tous eu des plats différents et nous sommes tous partis avec un sourire sur le visage. Comme signalé dans d'autres commentaires, le restaurant a une très bonne ambiance et le propriétaire charmant. Merci TripAdvisor.", 5.0, '14', 'octobre', '2013', "J'ai", 'passé', 'TripAdvisor.Plus')
# (8218, 9, 84, 'Un service extraordinaire', "Quel excellent restaurant, tenu par une belle famille. On se sent comme si vous êtes dans vos oncles pour le dîner. L'ambiance et le service faite pour la nourriture, ce qui était bien, mais un peu moins que ce à quoi je m'attendais. Super rapport qualité/prix, du début à la fin quand même l'un des meilleurs nuits nous avons eu", 4.0, '12', 'octobre', '2013', 'oct.', '2013', 'business')
# (8219, 9, 1, 'La cuisine est de première classe et un service à un prix raisonnable !', "J'ai voyagé dans près de 70 pays et ont essayé la meilleure nourriture venant du monde entier. D'une certaine manière c'est vrai Lyon, France a la meilleure nourriture. Cependant, je pense que la plupart des restaurants étoiles Mechelin sont surestimé. Une fois qu'ils auront la prime ils augmenter les prix, le service et la qualité de la nourriture diminue lentement. Les nombreux restaurants deviennent trop fiers de ces récompenses et finalement qu'essayer de maintenir ce qu'ils ont accompli. plutôt que de continuer à améliorer. C'est pourquoi ce restaurant est un petit bijou. Il est modeste et travaille dur pour satisfaire ses clients. Mais la nourriture est à la hauteur ou mieux que beaucoup de ces restaurants hors de prix. Vous aurez le meilleur des deux mondes. La cuisine est de première classe et le service pour un prix raisonnable. Le personnel de ce restaurant sont vraiment sincères les gens. Cela rend le goût de la nourriture tous les mieux", 5.0, '12', 'septembre', '2013', 'sept.', '2013', 'solo')
# (8220, 9, 6, 'La nourriture délicieuse, un excellent rapport qualité/prix !', 'Un hôtel très confortable, chaleureux restaurant. Le propriétaire/chef était très sympathique et serviable et a traduit tout le menu pour nous. Les plats étaient excellents pour un prix très raisonnable. Nous y retournerons certainement la prochaine fois à Lyon !', 5.0, '31', 'juillet', '2013', 'juil.', '2013', 'couples')
# (8221, 9, 11, 'Une expérience à ne pas manquer', "Après avoir lu les commentaires sur ce restaurant sur TripAdvisor, nous avons décidé de réserver une table pour un vendredi soir. Réservation était indispensable car le restaurant était plein. Le repas était l'un des meilleurs que j'aie eu en France. Une entrée de salade d'aubergines qui était léger mais pleine de saveur suivie d'un morceau superbement cuisinés de foie de veau. Nous avons essayé de réserver une autre table pour la nuit suivante mais ils étaient complets et très désolé. Tous les commentaires que vous lisez ce restaurant sont exactes, et ça vaut le détour.", 5.0, '19', 'juillet', '2013', 'juil.', '2013', 'couples')
# (8222, 9, 32, 'Musée Saint-Pierre', 'Situé dans le Palais Saint-Pierre, le plus beau musée traditionnel en Europe', 4.0, '12', 'mars', '2012', 'Situé', 'dans', 'EuropePlus')
# (8223, 9, 35, 'La nourriture est excellente, très bonne ambiance.', "Un bouchon traditionnel dans le centre de Lyon, avec une excellente nourriture et un propriétaire adorable qui était prêt à expliquer le menu très varié et de partager avec nous ses histoires sur la base de l'histoire de la ville.\nAssurez-vous que vous avez faim et ont fait des réservations. Il faut savoir que l'endroit est assez petit et peut-être un peu cher.", 4.0, '4', 'mars', '2012', 'mars', '2012', 'none')
# (8224, 9, 2, "N'aurait pas pu être mieux", "Assurez-vous de vous réserver une table. Assurez-vous que vous avez faim avant d'y aller. Écoutez Luc. Vous ne serez pas déçus. sans prétention, nourriture fantastique. Détendez-vous et profitez-en.", 5.0, '13', 'février', '2012', 'févr.', '2012', 'none')
# (8225, 9, 155, 'cuisine traditionnelle parfait dans une ville paradis des amateurs de nourriture, ne ratez pas cet endroit !', "J'ai emmené un groupe de 10 (!) dans cet hôtel et j'ai trouvé que le plus chaleureux, amusant, la réception et tous les services. Nous avons pris la plupart de ce qu'il y avait sur le menu, et tout le monde était impressionnés par avantages. Le clou personnelle était la quennelle de Pike Place. Bons vins de la maison et une visite de son traboule au restaurant complet, avant dessert, font de cet hôtel un vraiment soirée inoubliable. A ne pas manquer", 5.0, '9', 'novembre', '2010', "J'ai", 'emmené', 'manquerPlus')
